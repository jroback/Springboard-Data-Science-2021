# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Summary" data-toc-modified-id="Summary-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Summary</a></span><ul class="toc-item"><li><span><a href="#Findings" data-toc-modified-id="Findings-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Findings</a></span></li></ul></li><li><span><a href="#BAV-Data-Pre-Processing" data-toc-modified-id="BAV-Data-Pre-Processing-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>BAV Data Pre-Processing</a></span><ul class="toc-item"><li><span><a href="#Imports" data-toc-modified-id="Imports-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Imports</a></span></li><li><span><a href="#Quick-look-at-the-data" data-toc-modified-id="Quick-look-at-the-data-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Quick look at the data</a></span></li><li><span><a href="#Encoding" data-toc-modified-id="Encoding-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Encoding</a></span></li><li><span><a href="#Isolating-the-Target-Variable" data-toc-modified-id="Isolating-the-Target-Variable-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Isolating the Target Variable</a></span></li><li><span><a href="#PCA-With-Scaling" data-toc-modified-id="PCA-With-Scaling-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>PCA With Scaling</a></span></li><li><span><a href="#PCA-Without-Scaling" data-toc-modified-id="PCA-Without-Scaling-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>PCA Without Scaling</a></span></li></ul></li><li><span><a href="#Next-Steps" data-toc-modified-id="Next-Steps-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Next Steps</a></span><ul class="toc-item"><li><span><a href="#File-Save-Outs" data-toc-modified-id="File-Save-Outs-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>File Save Outs</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Summary

# %% [markdown]
# The goal of this notebook is to attempt to reduce the dimensionality of the BAV data and address any data scaling issues.
#
# Tecniques explored included PCA with 2 components and PCA at a 90% explained variance threshold (determined by SKLearn) on both scaled and unscaled data.

# %% [markdown]
# ### Findings

# %% [markdown]
# - Overall, the PCA worked to explain more variance in the dataset without scaling than with. However, while the reduction from 55 features to 15 was significant, the loss in interpretability was drastic. The results of modeling data in this form would be difficult to explain and impossible to interpret.
#
#
# - Because of the loss of interpretablilty, PCA is not a viable option for dimensionality reduction on the BAV data. As this work moves into the modeling phase, there are some other techniques that may prove valuable to explore.
#
#
# - I'm specifically interested to explore the effects of: High Correlation Filtering, Low Variance Filtering, and Random Forrests for Column Selection as outlined in this article:
# https://thenewstack.io/3-new-techniques-for-data-dimensionality-reduction-in-machine-learning/

# %% [markdown]
# ## BAV Data Pre-Processing

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
import os
import numpy as np
import time

from pandas_datareader import data as pdr
from scipy.stats import norm
from IPython import display
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Quick look at the data

# %%
# Load the Joined BAV data from EDA stage
BAV_df = pd.read_csv('../data/BAV_join.csv', header=0, index_col=0)
BAV_df.head()
# Out:
#               Recommend_to_a_friend_pct  Energized_Differentiation_C  \
# Acura                          9.632626                     0.588681
# Alfa Romeo                     5.360558                     0.771191
# Aston Martin                   6.165359                     0.777430
# Audi                           8.403893                     0.773740
# Bentley                        6.453038                     0.790917
#
#               Relevance_C  Esteem_C  Knowledge_C  Brand_Stature_C  \
# Acura            2.131318  0.536944     3.303892         1.774005
# Alfa Romeo       1.648400  0.351125     2.040411         0.716439
# Aston Martin     1.568270  0.347223     2.272228         0.788971
# Audi             1.970076  0.536370     3.247704         1.741970
# Bentley          1.605834  0.500165     2.720615         1.360756
#
#               Brand_Strength_C  Different_pct  Distinctive_pct  Unique_pct  \
# Acura                 1.254666       8.081687        12.271390    8.301122
# Alfa Romeo            1.271231      11.130420        17.817520   13.124450
# Aston Martin          1.219220      11.082860        18.486561   13.061050
# Audi                  1.524328       9.503444        16.048050   11.872650
# Bentley               1.270082      11.227820        19.309050   14.956740
#
#               ...  Stylish_pct  Traditional_pct  Trendy_pct  Trustworthy_pct  \
# Acura         ...    15.710160         6.446314    14.55371        16.099440
# Alfa Romeo    ...    17.267210         7.225183    14.87083         9.865144
# Aston Martin  ...    16.646311         5.149739    12.15355         9.925730
# Audi          ...    18.800541         8.386318    15.85582        12.400040
# Bentley       ...    19.569870        11.032830    12.52582        12.685470
#
#               Unapproachable_pct  Up_To_Date_pct  Upper_Class_pct  \
# Acura                   5.703656       11.032270        15.302950
# Alfa Romeo             10.311310       10.518590        25.941139
# Aston Martin            9.625601        7.878853        30.506660
# Audi                    6.730000       10.951970        21.809719
# Bentley                11.473560        9.141562        34.941780
#
#               Visionary_pct  Worth_More_pct  Year
# Acura             12.951940        6.352579  2018
# Alfa Romeo         9.230522        8.130341  2018
# Aston Martin      10.001760        8.295667  2018
# Audi              11.357830        8.388798  2018
# Bentley            9.720911       10.133530  2018
#
# [5 rows x 56 columns]

# %%
BAV_df.describe()
# Out:
#        Recommend_to_a_friend_pct  Energized_Differentiation_C  Relevance_C  \
# count                6058.000000                  6058.000000  6058.000000
# mean                   12.209701                     0.588415     2.544035
# std                     8.713072                     0.121253     0.537333
# min                     0.000000                     0.311086     0.844490
# 25%                     5.847472                     0.504416     2.194867
# 50%                     9.905344                     0.571779     2.465221
# 75%                    16.737939                     0.651827     2.809550
# max                    50.524490                     1.298806     5.316035
#
#           Esteem_C  Knowledge_C  Brand_Stature_C  Brand_Strength_C  \
# count  6058.000000  6058.000000      6058.000000       6058.000000
# mean      0.477370     2.414359         1.303382          1.505913
# std       0.212133     1.138746         1.146969          0.487146
# min       0.040534     0.361947         0.063010          0.323127
# 25%       0.336441     1.405593         0.481978          1.182708
# 50%       0.420696     2.403746         0.934364          1.435254
# 75%       0.566624     3.309856         1.711841          1.739238
# max       1.729260     5.400015         9.338032          6.904500
#
#        Different_pct  Distinctive_pct   Unique_pct  ...  Stylish_pct  \
# count    6058.000000      6058.000000  6058.000000  ...  6058.000000
# mean        9.397467        11.285562     9.608629  ...     7.968883
# std         2.483562         2.635689     2.600862  ...     4.555316
# min         1.993662         3.848764     2.237904  ...     0.957738
# 25%         7.553335         9.481501     7.762816  ...     5.082789
# 50%         8.978947        10.893910     9.208430  ...     6.409295
# 75%        10.843252        12.596953    11.000907  ...     9.035676
# max        27.744989        29.265770    28.022829  ...    32.493820
#
#        Traditional_pct   Trendy_pct  Trustworthy_pct  Unapproachable_pct  \
# count      6058.000000  6058.000000      6058.000000         6058.000000
# mean         10.177757    12.280784        15.192883            5.445757
# std           4.021893     4.398676         5.227095            2.280908
# min           2.520318     1.168887         2.830153            0.000000
# 25%           7.423602     9.070712        11.420812            4.006169
# 50%           9.271638    11.455115        14.337950            4.950425
# 75%          11.916027    14.547902        18.198491            6.349181
# max          44.155819    33.851509        38.595451           30.147461
#
#        Up_To_Date_pct  Upper_Class_pct  Visionary_pct  Worth_More_pct  \
# count     6058.000000      6058.000000    6058.000000     6058.000000
# mean        10.849244         8.087944      10.250318        6.298799
# std          2.704662         4.441919       3.231548        2.558453
# min          0.743542         0.777813       1.619330        0.000000
# 25%          9.046549         5.456322       8.055205        4.471148
# 50%         10.536130         6.766305       9.639658        5.844792
# 75%         12.262418         9.034813      11.721245        7.648178
# max         24.366600        39.617592      31.832420       20.036560
#
#               Year
# count  6058.000000
# mean   2018.500000
# std       0.500041
# min    2018.000000
# 25%    2018.000000
# 50%    2018.500000
# 75%    2019.000000
# max    2019.000000
#
# [8 rows x 56 columns]

# %%
BAV_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6058 entries, Acura to Thomson Reuters
# Data columns (total 56 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Recommend_to_a_friend_pct    6058 non-null   float64
#  1   Energized_Differentiation_C  6058 non-null   float64
#  2   Relevance_C                  6058 non-null   float64
#  3   Esteem_C                     6058 non-null   float64
#  4   Knowledge_C                  6058 non-null   float64
#  5   Brand_Stature_C              6058 non-null   float64
#  6   Brand_Strength_C             6058 non-null   float64
#  7   Different_pct                6058 non-null   float64
#  8   Distinctive_pct              6058 non-null   float64
#  9   Unique_pct                   6058 non-null   float64
#  10  Dynamic_pct                  6058 non-null   float64
#  11  Innovative_pct               6058 non-null   float64
#  12  Leader_pct                   6058 non-null   float64
#  13  Reliable_pct                 6058 non-null   float64
#  14  High_quality_pct             6058 non-null   float64
#  15  Arrogant_pct                 6058 non-null   float64
#  16  Authentic_pct                6058 non-null   float64
#  17  Best_Brand_pct               6058 non-null   float64
#  18  Carefree_pct                 6058 non-null   float64
#  19  Cares_Customers_pct          6058 non-null   float64
#  20  Charming_pct                 6058 non-null   float64
#  21  Cool_pct                     6058 non-null   float64
#  22  Creative_pct                 6058 non-null   float64
#  23  Daring_pct                   6058 non-null   float64
#  24  Down_to_Earth_pct            6058 non-null   float64
#  25  Energetic_pct                6058 non-null   float64
#  26  Friendly_pct                 6058 non-null   float64
#  27  Fun_pct                      6058 non-null   float64
#  28  Gaining_In_Popularity_pct    6058 non-null   float64
#  29  Glamorous_pct                6058 non-null   float64
#  30  Good_Value_pct               6058 non-null   float64
#  31  Healthy_pct                  6058 non-null   float64
#  32  Helpful_pct                  6058 non-null   float64
#  33  High_Performance_pct         6058 non-null   float64
#  34  Independent_pct              6058 non-null   float64
#  35  Intelligent_pct              6058 non-null   float64
#  36  Kind_pct                     6058 non-null   float64
#  37  Original_pct                 6058 non-null   float64
#  38  Prestigious_pct              6058 non-null   float64
#  39  Progressive_pct              6058 non-null   float64
#  40  Rugged_pct                   6058 non-null   float64
#  41  Sensuous_pct                 6058 non-null   float64
#  42  Simple_pct                   6058 non-null   float64
#  43  Social_pct                   6058 non-null   float64
#  44  Socially_Responsible_pct     6058 non-null   float64
#  45  Straightforward_pct          6058 non-null   float64
#  46  Stylish_pct                  6058 non-null   float64
#  47  Traditional_pct              6058 non-null   float64
#  48  Trendy_pct                   6058 non-null   float64
#  49  Trustworthy_pct              6058 non-null   float64
#  50  Unapproachable_pct           6058 non-null   float64
#  51  Up_To_Date_pct               6058 non-null   float64
#  52  Upper_Class_pct              6058 non-null   float64
#  53  Visionary_pct                6058 non-null   float64
#  54  Worth_More_pct               6058 non-null   float64
#  55  Year                         6058 non-null   int64
# dtypes: float64(55), int64(1)
# memory usage: 2.6+ MB

# %% [markdown]
# ### Encoding

# %% [markdown]
# First clean-up is the 'year' column. While it's a number, the scale is drastically different.

# %%
# Change 'year' to 'yr_2019' encoded with a 1 if true or 0 if 2018.
BAV_df['yr_2019'] = BAV_df['Year'].apply(lambda x: 0 if x==2018 else 1)

# %%
print(BAV_df['yr_2019'].sample(10))
# Out:
# Apple            1
# Alpo Snaps       1
# Genentech        0
# Lotrimin         0
# Planters         0
# Vespa            0
# Club Monaco      0
# MiraLAX          0
# ALDI             0
# Louis Vuitton    0
# Name: yr_2019, dtype: int64

# %%
BAV_df['yr_2019'].value_counts()
# Out:
# 0    3029
# 1    3029
# Name: yr_2019, dtype: int64

# %% [markdown]
# An even and equall number of 0s and 1s. As expected.
# Now drop the relic 'Year' column.

# %%
BAV_df = BAV_df.drop(['Year'], axis=1)
BAV_df.head(3)
# Out:
#               Recommend_to_a_friend_pct  Energized_Differentiation_C  \
# Acura                          9.632626                     0.588681
# Alfa Romeo                     5.360558                     0.771191
# Aston Martin                   6.165359                     0.777430
#
#               Relevance_C  Esteem_C  Knowledge_C  Brand_Stature_C  \
# Acura            2.131318  0.536944     3.303892         1.774005
# Alfa Romeo       1.648400  0.351125     2.040411         0.716439
# Aston Martin     1.568270  0.347223     2.272228         0.788971
#
#               Brand_Strength_C  Different_pct  Distinctive_pct  Unique_pct  \
# Acura                 1.254666       8.081687        12.271390    8.301122
# Alfa Romeo            1.271231      11.130420        17.817520   13.124450
# Aston Martin          1.219220      11.082860        18.486561   13.061050
#
#               ...  Stylish_pct  Traditional_pct  Trendy_pct  Trustworthy_pct  \
# Acura         ...    15.710160         6.446314    14.55371        16.099440
# Alfa Romeo    ...    17.267210         7.225183    14.87083         9.865144
# Aston Martin  ...    16.646311         5.149739    12.15355         9.925730
#
#               Unapproachable_pct  Up_To_Date_pct  Upper_Class_pct  \
# Acura                   5.703656       11.032270        15.302950
# Alfa Romeo             10.311310       10.518590        25.941139
# Aston Martin            9.625601        7.878853        30.506660
#
#               Visionary_pct  Worth_More_pct  yr_2019
# Acura             12.951940        6.352579        0
# Alfa Romeo         9.230522        8.130341        0
# Aston Martin      10.001760        8.295667        0
#
# [3 rows x 56 columns]

# %% [markdown]
# ### Isolating the Target Variable

# %%
X = BAV_df.drop(['Recommend_to_a_friend_pct'], axis=1)
y = BAV_df['Recommend_to_a_friend_pct']

# %% [markdown]
# ### PCA With Scaling

# %% [markdown]
# Before modeling, exploring ways to reduce the dimensionality of the dataset to simplify and speed up the process.
# Starting with a Principal Component Analysis.

# %%
scaler = StandardScaler()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3)

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# Start with scaling to 2 components
pca = PCA(n_components=2)
pc_train = pca.fit_transform(X_train)
principalComponents = pca.transform(X_test)
principal_BAV = pd.DataFrame(data = principalComponents, columns = ['pc 1', 'pc 2'])

# %%
y_test = pd.DataFrame(y_test)
principal_BAV.index = y_test.index

# %%
BAV_pca2_df = pd.concat([principal_BAV, y_test], axis=1)

# %%
BAV_pca2_df.sample(10)
# Out:
#                                  pc 1      pc 2  Recommend_to_a_friend_pct
# Urban Outfitters            -2.566193  2.218761                  11.119970
# Big Brothers Big Sisters     4.277704 -1.901640                  12.701690
# Allianz                     -2.982198 -1.426987                   3.377270
# VISA                         7.406398 -2.024941                  29.682289
# Australia                    0.436417  2.932212                  11.836110
# Lexus                        1.143027  4.973958                   9.613838
# Star Alliance               -4.001312 -0.210430                   4.549416
# Resolve (cleaning products)  0.469796 -4.731405                  20.721109
# Vera Wang                   -0.556680  6.352626                  11.186080
# Shark Tank                   1.061629  6.504978                  18.067471

# %%
# Ensuring we still have the same number of columns as before (30% of 6058 = 1818)
BAV_pca2_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1818 entries, Stephen Curry to LenovoEMC
# Data columns (total 3 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   pc 1                       1818 non-null   float64
#  1   pc 2                       1818 non-null   float64
#  2   Recommend_to_a_friend_pct  1818 non-null   float64
# dtypes: float64(3)
# memory usage: 56.8+ KB

# %%
figure(figsize=(8, 6))
plt.scatter(BAV_pca2_df['pc 1'], BAV_pca2_df['pc 2'], alpha=.25)
plt.title('PCA 2 Components')
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.show()

# %%
pca.explained_variance_ratio_
# Out:
# array([0.24882496, 0.18087231])

# %%
print('Makes more sense why the 2 component PCA is largely a blob. The explained variance is only {}. Will have to try with a larger number of components'.format(pca.explained_variance_ratio_.sum()))
# Out:
# Makes more sense why the 2 component PCA is largely a blob. The explained variance is only 0.4296972726412425. Will have to try with a larger number of components

# %%
# Have SKLearn select the number of components to explain 90% of the variance
# Start by visualizing
pca = PCA()
pca_train = pca.fit(X_train)
pca_test = pca.transform(X_test)
figure(figsize=(8, 6))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.title('Variance Explained by Number of Components')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance');
plt.show()

# %% [markdown]
# Looks like 20 components will explain about 90% of the variance.
# Let's find out exactly how many.

# %%
pca = PCA(n_components = 0.9)
pca_train = pca.fit(X_train)
pca_test = pca.transform(X_test)
pca.n_components_
# Out:
# 21

# %%
# Reassemble X and y with 21 components
X = pd.DataFrame(data = pca.transform(X))
y = pd.DataFrame(y)
X.index = y.index
BAV_pca21_df = pd.concat([X, y], axis=1)

# %%
BAV_pca21_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6058 entries, Acura to Thomson Reuters
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   0                          6058 non-null   float64
#  1   1                          6058 non-null   float64
#  2   2                          6058 non-null   float64
#  3   3                          6058 non-null   float64
#  4   4                          6058 non-null   float64
#  5   5                          6058 non-null   float64
#  6   6                          6058 non-null   float64
#  7   7                          6058 non-null   float64
#  8   8                          6058 non-null   float64
#  9   9                          6058 non-null   float64
#  10  10                         6058 non-null   float64
#  11  11                         6058 non-null   float64
#  12  12                         6058 non-null   float64
#  13  13                         6058 non-null   float64
#  14  14                         6058 non-null   float64
#  15  15                         6058 non-null   float64
#  16  16                         6058 non-null   float64
#  17  17                         6058 non-null   float64
#  18  18                         6058 non-null   float64
#  19  19                         6058 non-null   float64
#  20  20                         6058 non-null   float64
#  21  Recommend_to_a_friend_pct  6058 non-null   float64
# dtypes: float64(22)
# memory usage: 1.2+ MB

# %%
BAV_pca21_df.sample(10)
# Out:
#                                    0          1          2          3  \
# creditcards.com            54.201818  18.595035  -3.465828  -5.560883
# Microsoft                  86.423980  28.148858  15.464335  -3.319038
# Abercrombie & Fitch        47.378462  32.138821  -8.437074  16.392839
# Oxygen                     48.615702  21.706598 -12.953217  -0.605762
# Syfy (channel)             56.834455  35.451705 -18.274692  -2.379688
# American Family Insurance  50.838108   9.052317  -5.793284  -2.938716
# North Korea                20.720372  26.838847   1.753086   2.651363
# Novo Nordisk               52.917828  19.588237  -1.070467  -2.515967
# Kevlar                     63.631078  22.204747   3.704600   4.531118
# Credit Suisse              41.933677  20.800010  -0.284204   2.300587
#
#                                    4          5          6          7  \
# creditcards.com            -6.764918  12.916266   0.529816 -11.911032
# Microsoft                  -1.237943   9.067289  -5.141479  -7.040141
# Abercrombie & Fitch        -7.147483   9.494191  -7.283328 -12.444844
# Oxygen                      0.150157  13.392239  -1.582160  -7.318009
# Syfy (channel)             12.116770   4.420609   2.950589  -0.848894
# American Family Insurance  -5.041904  16.150299   0.073044  -9.809376
# North Korea                 7.880505  25.228177   8.426180  -0.739220
# Novo Nordisk               -6.712127  11.373453   3.229004  -9.493812
# Kevlar                     -2.348803   1.607228  11.796414 -10.742910
# Credit Suisse              -5.407292  13.682033   0.291834  -8.070035
#
#                                   8          9  ...        12         13  \
# creditcards.com           -0.370112   8.808196  ...  2.929560   0.451455
# Microsoft                  0.377537   5.190057  ...  1.084604  -3.265521
# Abercrombie & Fitch        1.770378  12.490536  ...  2.748454  -3.595576
# Oxygen                    -1.077903   5.686585  ...  1.637493  -0.441307
# Syfy (channel)             4.262325   3.373961  ...  3.719323  -2.144639
# American Family Insurance  3.240742   5.154227  ...  2.311789  -2.493729
# North Korea                9.377598  27.203349  ... -1.539967 -10.584552
# Novo Nordisk               2.237752   3.849440  ... -0.695245  -0.495758
# Kevlar                     2.369041   2.629915  ...  2.384137  -5.769376
# Credit Suisse              4.133566   4.135282  ... -2.867302  -1.485224
#
#                                   14        15        16        17         18  \
# creditcards.com           -11.223419  4.344647  0.944479  1.575373  16.556048
# Microsoft                 -15.528401  6.908675 -5.080359 -3.974249  20.000488
# Abercrombie & Fitch       -16.020290  1.585366 -2.655007 -3.738686   9.344716
# Oxygen                    -10.437296  4.539946 -0.132517 -2.041688  13.498317
# Syfy (channel)            -11.110487  7.358783  2.163008 -5.953401  14.994496
# American Family Insurance  -9.344021  4.837737  1.053003  0.057245  13.955986
# North Korea                -5.698278  0.895576 -3.381984 -3.885915   7.363183
# Novo Nordisk              -14.464201  2.503905  1.523689 -6.262144  15.379867
# Kevlar                    -10.043453  6.913466 -5.081561 -1.306955  16.570514
# Credit Suisse             -10.858450  4.442240  0.808574 -0.364700  10.950325
#
#                                   19        20  Recommend_to_a_friend_pct
# creditcards.com             4.466770 -2.584621                   4.356225
# Microsoft                  10.678474 -2.976477                  29.577900
# Abercrombie & Fitch         2.990813 -5.081314                  12.608980
# Oxygen                      3.884442 -4.913475                  10.691210
# Syfy (channel)              4.319138  0.814595                  18.561899
# American Family Insurance   4.751938 -3.740074                   5.974168
# North Korea                 6.414220 -3.881655                   4.281029
# Novo Nordisk                7.219052 -5.881075                   0.000000
# Kevlar                      8.276834 -3.737904                   8.233458
# Credit Suisse               4.350026 -4.225334                   3.482583
#
# [10 rows x 22 columns]

# %% [markdown]
# ### PCA Without Scaling

# %%
# Have SKLearn select the number of components to explain 90% of the variance
# Start by visualizing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3)

pca_ns = PCA()
pca_train_ns = pca_ns.fit(X_train)
pca_test_ns = pca_ns.transform(X_test)
figure(figsize=(8, 6))
plt.plot(np.cumsum(pca_ns.explained_variance_ratio_))
plt.title('Variance Explained by Number of Components')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance');
plt.show()

# %% [markdown]
# Without scaling seems to eplain more variance by using less components.
# Let's compute the 90% threshold.

# %%
pca_ns = PCA(n_components = 0.9)
pca_train_ns = pca_ns.fit(X_train)
pca_test_ns = pca_ns.transform(X_test)
pca_ns.n_components_
# Out:
# 9

# %%
# Reassemble DataFrame with 9 components
X = pd.DataFrame(data = pca_ns.transform(X))
y = pd.DataFrame(y)
X.index = y.index
BAV_pca9_df = pd.concat([X, y], axis=1)
BAV_pca9_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6058 entries, Acura to Thomson Reuters
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   0                          6058 non-null   float64
#  1   1                          6058 non-null   float64
#  2   2                          6058 non-null   float64
#  3   3                          6058 non-null   float64
#  4   4                          6058 non-null   float64
#  5   5                          6058 non-null   float64
#  6   6                          6058 non-null   float64
#  7   7                          6058 non-null   float64
#  8   8                          6058 non-null   float64
#  9   Recommend_to_a_friend_pct  6058 non-null   float64
# dtypes: float64(10)
# memory usage: 649.6+ KB

# %%
BAV_pca9_df.sample(10)
# Out:
#                             0          1          2          3          4  \
# Crystal Light       11.809182  -2.288150 -11.320860   4.839018   4.859450
# Jameson             -9.337473  -1.214445  -3.112411   3.625538 -11.033857
# San Pellegrino      -6.517941  -5.808237  -0.886018   9.359412   0.872207
# Diesel (clothing)  -15.933761   4.859958  -0.955148   7.801997   1.896333
# Judaism (religion) -13.862287 -18.695312  -5.181016  -6.886769  -9.202006
# Nexxus              -7.088632  -7.298443   5.207173   6.645959  -0.039224
# Bridgestone          9.567115  -3.212865  12.748732  -3.701748 -10.062765
# Pretzel Crisps       3.243312  -3.427697 -14.610117   4.613724   5.751008
# Banquet             16.848642 -11.518122 -10.020155   3.480844  -3.136841
# Google              21.912797  33.474766  22.225956 -23.162003   4.846439
#
#                            5          6         7         8  \
# Crystal Light       2.872210  -1.472457 -1.458693  1.817653
# Jameson             3.423720   0.671664 -2.379148  0.170156
# San Pellegrino      2.438402   0.452546 -3.861869 -0.019518
# Diesel (clothing)  -6.477051  -7.531801  4.370113  1.964740
# Judaism (religion)  3.202245  10.702605 -1.867274  5.604087
# Nexxus             -1.448235  -1.808570 -3.380233 -2.871175
# Bridgestone        -1.887234  -7.320252  5.596333 -3.205523
# Pretzel Crisps      3.790245  -2.356573 -2.989599  3.819639
# Banquet            -5.792499   2.041160  2.177752  2.290946
# Google             -2.908103  -1.347840 -5.960109  3.144561
#
#                     Recommend_to_a_friend_pct
# Crystal Light                       19.736490
# Jameson                             11.010470
# San Pellegrino                      10.535250
# Diesel (clothing)                    6.328249
# Judaism (religion)                   0.000000
# Nexxus                              11.552280
# Bridgestone                         18.744120
# Pretzel Crisps                      13.555260
# Banquet                             20.199869
# Google                              47.268650

# %% [markdown]
# ## Next Steps

# %% [markdown]
# Because of the loss of interpretablilty, PCA is not a viable option for dimensionality reduction on the BAV data—at least for explanatory puposes. As this work moves into the modeling phase, there are some other techniques that may prove valuable to explore in understanding and communicating the workings of the model.
#
# I will reatin the PCA 9 reduced dataset for prediction purposes, in case there is a need for a separate prediction model.
#
# I'm specifically interested to explore the effects of: High Correlation Filtering, Low Variance Filtering, and Random Forrests for Column Selection as outlined in this article:
# https://thenewstack.io/3-new-techniques-for-data-dimensionality-reduction-in-machine-learning/

# %% [markdown]
# ### File Save Outs

# %%
# Assembling standard scaled dataset for save out
X_ = BAV_df.drop(['Recommend_to_a_friend_pct'], axis=1)
Xs_df = pd.DataFrame(data=scaler.transform(X_), columns=X_.columns)
Xs_df.index = y.index
BAV_scaled = pd.concat([y, Xs_df], axis=1)
BAV_scaled.head()
# Out:
#               Recommend_to_a_friend_pct  Energized_Differentiation_C  \
# Acura                          9.632626                    -0.002347
# Alfa Romeo                     5.360558                     1.509067
# Aston Martin                   6.165359                     1.560737
# Audi                           8.403893                     1.530181
# Bentley                        6.453038                     1.672423
#
#               Relevance_C  Esteem_C  Knowledge_C  Brand_Stature_C  \
# Acura           -0.787306  0.276346     0.782062         0.408922
# Alfa Romeo      -1.696354 -0.596668    -0.322769        -0.512688
# Aston Martin    -1.847191 -0.615000    -0.120060        -0.449481
# Audi            -1.090829  0.273648     0.732929         0.381005
# Bentley         -1.776480  0.103549     0.272025         0.048799
#
#               Brand_Strength_C  Different_pct  Distinctive_pct  Unique_pct  \
# Acura                -0.532561      -0.534627         0.374604   -0.505916
# Alfa Romeo           -0.498050       0.686925         2.491879    1.336199
# Aston Martin         -0.606405       0.667869         2.747290    1.311986
# Audi                  0.029230       0.035036         1.816371    0.858114
# Bentley              -0.500444       0.725951         3.061281    2.035984
#
#               ...  Stylish_pct  Traditional_pct  Trendy_pct  Trustworthy_pct  \
# Acura         ...     1.700738        -0.953525    0.524561         0.172321
# Alfa Romeo    ...     2.043090        -0.756703    0.596944        -1.014161
# Aston Martin  ...     1.906571        -1.281172   -0.023276        -1.002630
# Audi          ...     2.380227        -0.463282    0.821769        -0.531731
# Bentley       ...     2.549381         0.205497    0.061694        -0.477410
#
#               Unapproachable_pct  Up_To_Date_pct  Upper_Class_pct  \
# Acura                   0.111888        0.067217         1.632785
# Alfa Romeo              2.144682       -0.124812         4.041739
# Aston Martin            1.842162       -1.111623         5.075575
# Audi                    0.564688        0.037198         3.106204
# Bentley                 2.657441       -0.639585         6.079881
#
#               Visionary_pct  Worth_More_pct   yr_2019
# Acura              0.832706        0.012613 -0.977609
# Alfa Romeo        -0.315579        0.703253 -0.977609
# Aston Martin      -0.077605        0.767481 -0.977609
# Audi               0.340826        0.803661 -0.977609
# Bentley           -0.164264        1.481469 -0.977609
#
# [5 rows x 56 columns]

# %%
# Reminder of unscaled dataset
BAV_df.head()
# Out:
#               Recommend_to_a_friend_pct  Energized_Differentiation_C  \
# Acura                          9.632626                     0.588681
# Alfa Romeo                     5.360558                     0.771191
# Aston Martin                   6.165359                     0.777430
# Audi                           8.403893                     0.773740
# Bentley                        6.453038                     0.790917
#
#               Relevance_C  Esteem_C  Knowledge_C  Brand_Stature_C  \
# Acura            2.131318  0.536944     3.303892         1.774005
# Alfa Romeo       1.648400  0.351125     2.040411         0.716439
# Aston Martin     1.568270  0.347223     2.272228         0.788971
# Audi             1.970076  0.536370     3.247704         1.741970
# Bentley          1.605834  0.500165     2.720615         1.360756
#
#               Brand_Strength_C  Different_pct  Distinctive_pct  Unique_pct  \
# Acura                 1.254666       8.081687        12.271390    8.301122
# Alfa Romeo            1.271231      11.130420        17.817520   13.124450
# Aston Martin          1.219220      11.082860        18.486561   13.061050
# Audi                  1.524328       9.503444        16.048050   11.872650
# Bentley               1.270082      11.227820        19.309050   14.956740
#
#               ...  Stylish_pct  Traditional_pct  Trendy_pct  Trustworthy_pct  \
# Acura         ...    15.710160         6.446314    14.55371        16.099440
# Alfa Romeo    ...    17.267210         7.225183    14.87083         9.865144
# Aston Martin  ...    16.646311         5.149739    12.15355         9.925730
# Audi          ...    18.800541         8.386318    15.85582        12.400040
# Bentley       ...    19.569870        11.032830    12.52582        12.685470
#
#               Unapproachable_pct  Up_To_Date_pct  Upper_Class_pct  \
# Acura                   5.703656       11.032270        15.302950
# Alfa Romeo             10.311310       10.518590        25.941139
# Aston Martin            9.625601        7.878853        30.506660
# Audi                    6.730000       10.951970        21.809719
# Bentley                11.473560        9.141562        34.941780
#
#               Visionary_pct  Worth_More_pct  yr_2019
# Acura             12.951940        6.352579        0
# Alfa Romeo         9.230522        8.130341        0
# Aston Martin      10.001760        8.295667        0
# Audi              11.357830        8.388798        0
# Bentley            9.720911       10.133530        0
#
# [5 rows x 56 columns]

# %%
BAV_df.to_csv("../data/BAV_unscaled.csv")
BAV_scaled.to_csv("../data/BAV_scaled.csv")
BAV_pca9_df.to_csv("../data/BAV_pca9.csv")
