# %% [markdown]
# ### BAV Data Pre-Processing

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import numpy as np
import time

from pandas_datareader import data as pdr
from scipy.stats import norm
from IPython import display
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import minmax_scale

# %% [markdown]
# #### Quick look at the data

# %%
# Load the Joined BAV data from EDA
BAV_df = pd.read_csv('../data/BAV_join.csv', header=0, index_col=0)
BAV_df.head()
# Out:
#               Recommend_to_a_friend_pct  Energized_Differentiation_C  \
# Acura                          9.632626                     0.588681
# Alfa Romeo                     5.360558                     0.771191
# Aston Martin                   6.165359                     0.777430
# Audi                           8.403893                     0.773740
# Bentley                        6.453038                     0.790917
#
#               Relevance_C  Esteem_C  Knowledge_C  Brand_Stature_C  \
# Acura            2.131318  0.536944     3.303892         1.774005
# Alfa Romeo       1.648400  0.351125     2.040411         0.716439
# Aston Martin     1.568270  0.347223     2.272228         0.788971
# Audi             1.970076  0.536370     3.247704         1.741970
# Bentley          1.605834  0.500165     2.720615         1.360756
#
#               Brand_Strength_C  Different_pct  Distinctive_pct  Unique_pct  \
# ...

# %%
BAV_df.describe()
# Out:
#        Recommend_to_a_friend_pct  Energized_Differentiation_C  Relevance_C  \
# count                5738.000000                  5738.000000  5738.000000
# mean                   12.878115                     0.587120     2.546743
# std                     8.453313                     0.120728     0.530302
# min                     1.825505                     0.311086     1.038706
# 25%                     6.403312                     0.503263     2.196403
# 50%                    10.373855                     0.570438     2.467949
# 75%                    17.249875                     0.650969     2.813291
# max                    50.524490                     1.298806     5.316035
#
#           Esteem_C  Knowledge_C  Brand_Stature_C  Brand_Strength_C  \
# count  5738.000000  5738.000000      5738.000000       5738.000000
# mean      0.477173     2.423930         1.309063          1.503495
# std       0.211636     1.133079         1.149767          0.481468
# ...

# %%
BAV_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5738 entries, Acura to Thomson Reuters
# Data columns (total 56 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Recommend_to_a_friend_pct    5738 non-null   float64
#  1   Energized_Differentiation_C  5738 non-null   float64
#  2   Relevance_C                  5738 non-null   float64
#  3   Esteem_C                     5738 non-null   float64
#  4   Knowledge_C                  5738 non-null   float64
#  5   Brand_Stature_C              5738 non-null   float64
#  6   Brand_Strength_C             5738 non-null   float64
#  7   Different_pct                5738 non-null   float64
#  8   Distinctive_pct              5738 non-null   float64
#  9   Unique_pct                   5738 non-null   float64
#  10  Dynamic_pct                  5738 non-null   float64
#  11  Innovative_pct               5738 non-null   float64
# ...

# %% [markdown]
# #### 1. Encoding

# %% [markdown]
# First clean-up is the 'year' column. While it's a number, the scale is drastically different. Plan is to change 'year' to 'yr_2019' encoded with a 1 if it is and a 0 if 2018.

# %%
BAV_df['yr_2019'] = BAV_df['Year'].apply(lambda x: 0 if x==2018 else 1)

# %%
print(BAV_df['yr_2019'].sample(10))
# Out:
# Emeril`s                           0
# Pringles                           1
# Grohe                              0
# The Leading Hotels of the World    0
# EarthLink                          1
# The Today Show                     0
# Athleta                            0
# Goodyear                           1
# Hunt`s Snack Pack                  1
# Business Insider                   1
# Name: yr_2019, dtype: int64

# %%
BAV_df['yr_2019'].value_counts()
# Out:
# 1    2869
# 0    2869
# Name: yr_2019, dtype: int64

# %% [markdown]
# Great. Even and equall number of 0s and 1s. As expected. Now drop the relic 'Year' column.

# %%
BAV_df = BAV_df.drop(['Year'], axis=1)
BAV_df.head(3)
# Out:
#               Recommend_to_a_friend_pct  Energized_Differentiation_C  \
# Acura                          9.632626                     0.588681
# Alfa Romeo                     5.360558                     0.771191
# Aston Martin                   6.165359                     0.777430
#
#               Relevance_C  Esteem_C  Knowledge_C  Brand_Stature_C  \
# Acura            2.131318  0.536944     3.303892         1.774005
# Alfa Romeo       1.648400  0.351125     2.040411         0.716439
# Aston Martin     1.568270  0.347223     2.272228         0.788971
#
#               Brand_Strength_C  Different_pct  Distinctive_pct  Unique_pct  \
# Acura                 1.254666       8.081687        12.271390    8.301122
# Alfa Romeo            1.271231      11.130420        17.817520   13.124450
# Aston Martin          1.219220      11.082860        18.486561   13.061050
#
#               ...  Stylish_pct  Traditional_pct  Trendy_pct  Trustworthy_pct  \
# ...

# %% [markdown]
# #### Isolating target variable

# %%
X = BAV_df.drop(['Recommend_to_a_friend_pct'], axis=1)
y = BAV_df['Recommend_to_a_friend_pct']

# %% [markdown]
# #### 2. Scaling

# %% [markdown]
# The scales are a bit off for some of the columns. The '_C' aggrigate columns seem to be on a scale of 0-10, while the remainder range between 0-50. Since these are all positive values and want to allow for the weight of outliers, the solution will be to implement a Max Absolute scaler on all columns before diving into PCA to help narrow down the number
# of features.

# %%
scaler = MaxAbsScaler()
scaled_feats = scaler.fit_transform(X)

# %%
print(scaled_feats)
# Out:
# [[0.4532476  0.40092252 0.3105052  ... 0.42101358 0.31704939 0.        ]
#  [0.59376909 0.31008073 0.20304934 ... 0.30004581 0.40577527 0.        ]
#  [0.59857309 0.29500747 0.20079301 ... 0.32511552 0.41402649 0.        ]
#  ...
#  [0.52403996 0.44616772 0.36182546 ... 0.53512855 0.43081714 1.        ]
#  [0.4348825  0.44566734 0.28619936 ... 0.40431308 0.20847656 1.        ]
#  [0.41860956 0.46433387 0.24513983 ... 0.28636331 0.18494313 1.        ]]

# %%
# scale the output between 0 and 1 for the chart
yscale = pd.to_array(y)
y_scale = yscale.reshape(-1, 1)
scaled_y = scaler.fit_transform(y_scale)

plt.scatter(scaled_feats, scaled_y)
plt.title('Scaled Features with Recommend to a Friend')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-6fda933fbd52> in <module>
#       1 # scale the output between 0 and 1 for the chart
# ----> 2 yscale = pd.to_array(y)
#       3 y_scale = yscale.reshape(-1, 1)
#       4 scaled_y = scaler.fit_transform(y_scale)
#       5
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/__init__.py in __getattr__(name)
#     256             return _SparseArray
#     257
# --> 258         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     259
#     260
#
# AttributeError: module 'pandas' has no attribute 'to_array'

# %% [markdown]
# Note for Paolo: Not finished. Just where I've gotten to so far.
