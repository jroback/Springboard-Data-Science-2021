# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Summary-of-Analysis" data-toc-modified-id="Summary-of-Analysis-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Summary of Analysis</a></span><ul class="toc-item"><li><span><a href="#Intent" data-toc-modified-id="Intent-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Intent</a></span></li><li><span><a href="#Data" data-toc-modified-id="Data-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Data</a></span></li><li><span><a href="#Learnings" data-toc-modified-id="Learnings-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Learnings</a></span></li></ul></li><li><span><a href="#EDA" data-toc-modified-id="EDA-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>EDA</a></span><ul class="toc-item"><li><span><a href="#Imports-and-Helper-Functions" data-toc-modified-id="Imports-and-Helper-Functions-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Imports and Helper Functions</a></span></li><li><span><a href="#Cleanup" data-toc-modified-id="Cleanup-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Cleanup</a></span><ul class="toc-item"><li><span><a href="#Dimesnionality-Reduction" data-toc-modified-id="Dimesnionality-Reduction-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Dimesnionality Reduction</a></span></li></ul></li><li><span><a href="#Summary-Statistics" data-toc-modified-id="Summary-Statistics-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Summary Statistics</a></span></li><li><span><a href="#Create-New-DataFrame-for-Stock-Data" data-toc-modified-id="Create-New-DataFrame-for-Stock-Data-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Create New DataFrame for Stock Data</a></span><ul class="toc-item"><li><span><a href="#Changing-the-Target-Variable" data-toc-modified-id="Changing-the-Target-Variable-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Changing the Target Variable</a></span></li></ul></li></ul></li><li><span><a href="#Changing-the-Target-Variable" data-toc-modified-id="Changing-the-Target-Variable-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Changing the Target Variable</a></span><ul class="toc-item"><li><span><a href="#Option-B:-'Recommend-to-a-Friend'" data-toc-modified-id="Option-B:-'Recommend-to-a-Friend'-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Option B: 'Recommend to a Friend'</a></span></li><li><span><a href="#Merging-the-2018-and-2019-Data" data-toc-modified-id="Merging-the-2018-and-2019-Data-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Merging the 2018 and 2019 Data</a></span></li><li><span><a href="#Visualizations" data-toc-modified-id="Visualizations-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Visualizations</a></span></li><li><span><a href="#Experiment" data-toc-modified-id="Experiment-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Experiment</a></span></li><li><span><a href="#Save-Outs" data-toc-modified-id="Save-Outs-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Save Outs</a></span></li><li><span><a href="#Next-Steps" data-toc-modified-id="Next-Steps-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Next Steps</a></span></li></ul></li></ul></div>

# %% [markdown]
# ## Summary of Analysis

# %% [markdown]
# ### Intent

# %% [markdown]
# In this notebook I perform an exploratory data analysis (EDA) on the Brand Asset Valuator (BAV) datasets for 2018 and 2019. The goal of this EDA is to find trends, patterns or correlations in the dataset that are useful on their own or can be used to inform modeling decisions.

# %% [markdown]
# ### Data

# %% [markdown]
# ***Note*** The scale of the columns has changed from the Data Wrangling phase. In the data wrangling phase, we were looking at percentile scores ('_R' columns) of the survey response data which was solving too much of the variation in our data to observe the true change. Switching to the raw, '_pct' columns allows us to see more of the true variability from year to year. These columns will be used going forward.

# %% [markdown]
# ### Learnings

# %% [markdown]
# - The target variable was identified as the likelihood to 'Recommend [the brand] to a Friend'. Note that this is different from the planned target of 'Brand Market Capitalization' pulled from historic stock market data. It was discovered midway through this notebook that—after joining the available data with their matched ticker symbols—that the number of discrepencies and redundancies in the stock data wasn't worth the effort. Resolving the errors (over 700) would have to be done manually and the available 'Recommend to Friend' value was determined to be as good of a proxy for a change in year-over-year brand perception.
#
#
# - Less than 10% of the target variable values for the available brands are missing. This is due to the fact that either these brands are less well known or not used by those surveyed in as part of the sample. Visualizations showed that brands with these missing values (in the form of zeros) did not widely differ in the distributions of their explanatory features, and these brands were retained in the dataset.
#
#
# - The identified target feature of 'Recommend to a Friend' is influenced by a number of features. While the Differentiation_c was found to play less of a role, the other aggrigate attributes of Strength, Relevance, Esteem and Knowledge are all top correlators. Additional raw features like Best Brand, Down to Earth, and Trustworthy are all contributors as well. After exploring relationships with the target feature, an additional expirment was conducted  on a single feature (Socially Responsible) to explore the trend of its year-over-year attribute change. No significance was found between independant variables like Socially Responsible (p-Value >0.15) between 2018 and 2019. This is good to know as as we move into the next phase.

# %% [markdown]
# ## EDA

# %% [markdown]
# ### Imports and Helper Functions

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sns
import os
import requests
import numpy as np
import time

import yfinance as yf
from pandas_datareader import data as pdr
from scipy.stats import norm
from IPython import display

# %%
def brand_glance(brand):
    i_brand = BAV_2019.index==brand
    quick_cols = ['Recommend_to_a_friend_pct', 'Brand_Stature_C', 'Brand_Strength_C']
    print(BAV_2019.iloc[i_brand][quick_cols])

# %%
def get_stock_data(ticker):
    """Uses a ticker symbol to pull financial data from Polygon API"""
    lookup_url = 'https://api.polygon.io/v2/reference/financials/'
    query = '?limit=3&type=T&apiKey=znY3_peGnZRXAcpXCeW3i2UVdCKz28Bq'
    stock_data = requests.get(lookup_url + ticker + query).json()
    
    return stock_data

# %%
def get_ticker_details(ticker):
    lookup_url = 'https://api.polygon.io/v1/meta/symbols/'
    query = '/company?&apiKey=znY3_peGnZRXAcpXCeW3i2UVdCKz28Bq'
    
    return requests.get(lookup_url + ticker + query).json()

# %%
def get_number_of_shares(ticker):
    """Uses a ticker symbol to pull the current number of shares from Yahoo Finance"""
    if not ticker:
        return None
    try:
        stock = yf.Tickers(ticker)
        return stock.tickers[0].info['sharesOutstanding']
    except:
        time.sleep(.1) # Slight pause every few calls so API doesn't timeout
        return None

# %%
def get_stock_prices(ticker, start_date, end_date):
    """Uses a ticker symbol to pull the stock price at a specific date from Yahoo Finance"""
    if not ticker:
        return None
    try:
        stock_prices_df = yf.download(tickers=ticker, start=start_date, end=end_date)
        begin_yr = stock_prices_df[0]['Adj Close']
        end_yr = stock_prices_df[-1]['Adj Close']
        return begin_yr, end_yr
    except:
        time.sleep(.1) # Slight pause every few calls so API doesn't timeout
        return None

# %% [markdown]
# ### Cleanup

# %% [markdown]
# There's still a bit more clean up to do on the stock data from the data wrangling stage.
# The intent is to get all of the unique ticker symbols and use those to bring in the most relevant financial data.

# %%
# Load the Clean 2019 BAV data from Data Wrangling phase
BAV_2019 = pd.read_csv('../data/BAV_2019.csv', header=0, index_col=0)

# Load the Clean 2018 BAV data from Data Wrangling phase
BAV_2018 = pd.read_csv('../data/BAV_2018.csv', header=0, index_col=0)

# %%
BAV_2018.shape
# Out:
# (3522, 155)

# %% [markdown]
# #### Dimesnionality Reduction
# * Problem:
# >I want to get the number of columns down from 150 to something more reasonable.
#
# * Solution:
# >I only need the '_pct' columns for analysis, so I will condense both years to just these columns and the other relevant string columns. This will reduce the dataframe to less than 60 features.

# %%
rel_cols = ['Brand_ID', 'Recommend_to_a_friend_pct', 'Energized_Differentiation_C', 'Relevance_C', 'Esteem_C', 'Knowledge_C', 'Brand_Stature_C', 'Brand_Strength_C', 'Different_pct', 'Distinctive_pct', 'Unique_pct', 'Dynamic_pct', 'Innovative_pct', 'Leader_pct', 'Reliable_pct', 'High_quality_pct', 'Arrogant_pct', 'Authentic_pct', 'Best_Brand_pct', 'Carefree_pct', 'Cares_Customers_pct', 'Charming_pct', 'Cool_pct', 'Creative_pct', 'Daring_pct', 'Down_to_Earth_pct', 'Energetic_pct', 'Friendly_pct', 'Fun_pct', 'Gaining_In_Popularity_pct', 'Glamorous_pct', 'Good_Value_pct', 'Healthy_pct', 'Helpful_pct', 'High_Performance_pct', 'Independent_pct', 'Intelligent_pct', 'Kind_pct', 'Original_pct', 'Prestigious_pct', 'Progressive_pct', 'Rugged_pct', 'Sensuous_pct', 'Simple_pct', 'Social_pct', 'Socially_Responsible_pct', 'Straightforward_pct', 'Stylish_pct', 'Traditional_pct', 'Trendy_pct', 'Trustworthy_pct', 'Unapproachable_pct', 'Up_To_Date_pct', 'Upper_Class_pct', 'Visionary_pct', 'Worth_More_pct', 'company', 'ticker_symbol']

# %%
BAV_2019_clean = BAV_2019[rel_cols]
BAV_2019_clean.head(3)
# Out:
#              Brand_ID  Recommend_to_a_friend_pct  Energized_Differentiation_C  \
# Company 2019
# Acura             AVE                   9.953999                     0.642188
# Alfa Romeo        CQK                   4.776871                     0.762568
# Aston Martin      MKU                   5.559846                     0.850419
#
#               Relevance_C  Esteem_C  Knowledge_C  Brand_Stature_C  \
# Company 2019
# Acura            2.139913  0.539018     3.184861         1.716698
# Alfa Romeo       1.758157  0.317809     2.082544         0.661852
# Aston Martin     1.654088  0.440287     2.108977         0.928555
#
#               Brand_Strength_C  Different_pct  Distinctive_pct  ...  \
# Company 2019                                                    ...
# Acura                 1.374227       8.288108        13.685770  ...
# Alfa Romeo            1.340714       9.912714        17.094549  ...
# Aston Martin          1.406667      11.399390        19.736879  ...
#
#               Traditional_pct  Trendy_pct  Trustworthy_pct  \
# Company 2019
# Acura                8.759768    14.57190        16.129530
# Alfa Romeo           7.273140    12.65383         8.988947
# Aston Martin         7.312238    13.29794        11.300640
#
#               Unapproachable_pct  Up_To_Date_pct  Upper_Class_pct  \
# Company 2019
# Acura                   5.455859       11.924330        16.334471
# Alfa Romeo              8.070658        9.083805        24.738430
# Aston Martin           10.102460        9.896882        28.885571
#
#               Visionary_pct  Worth_More_pct       company  ticker_symbol
# Company 2019
# Acura              12.20723        7.467402         Acura            NaN
# Alfa Romeo         10.36332        7.162646    Alfa Romeo            RMO
# Aston Martin       11.90374        7.692444  Aston Martin            NaN
#
# [3 rows x 58 columns]

# %%
BAV_2018_clean = BAV_2018[rel_cols]
BAV_2018_clean.head(3)
# Out:
#              Brand_ID  Recommend_to_a_friend_pct  Energized_Differentiation_C  \
# Company 2018
# Acura             AVE                   9.632626                     0.588681
# Alfa Romeo        CQK                   5.360558                     0.771191
# Aston Martin      MKU                   6.165359                     0.777430
#
#               Relevance_C  Esteem_C  Knowledge_C  Brand_Stature_C  \
# Company 2018
# Acura            2.131318  0.536944     3.303892         1.774005
# Alfa Romeo       1.648400  0.351125     2.040411         0.716439
# Aston Martin     1.568270  0.347223     2.272228         0.788971
#
#               Brand_Strength_C  Different_pct  Distinctive_pct  ...  \
# Company 2018                                                    ...
# Acura                 1.254666       8.081687        12.271390  ...
# Alfa Romeo            1.271231      11.130420        17.817520  ...
# Aston Martin          1.219220      11.082860        18.486561  ...
#
#               Traditional_pct  Trendy_pct  Trustworthy_pct  \
# Company 2018
# Acura                6.446314    14.55371        16.099440
# Alfa Romeo           7.225183    14.87083         9.865144
# Aston Martin         5.149739    12.15355         9.925730
#
#               Unapproachable_pct  Up_To_Date_pct  Upper_Class_pct  \
# Company 2018
# Acura                   5.703656       11.032270        15.302950
# Alfa Romeo             10.311310       10.518590        25.941139
# Aston Martin            9.625601        7.878853        30.506660
#
#               Visionary_pct  Worth_More_pct       company  ticker_symbol
# Company 2018
# Acura             12.951940        6.352579         Acura            NaN
# Alfa Romeo         9.230522        8.130341    Alfa Romeo            RMO
# Aston Martin      10.001760        8.295667  Aston Martin            NaN
#
# [3 rows x 58 columns]

# %% [markdown]
# ### Summary Statistics

# %%
BAV_2019_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3661 entries, Acura to Gogo Inflight
# Data columns (total 58 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Brand_ID                     3661 non-null   object
#  1   Recommend_to_a_friend_pct    3661 non-null   float64
#  2   Energized_Differentiation_C  3661 non-null   float64
#  3   Relevance_C                  3661 non-null   float64
#  4   Esteem_C                     3661 non-null   float64
#  5   Knowledge_C                  3661 non-null   float64
#  6   Brand_Stature_C              3661 non-null   float64
#  7   Brand_Strength_C             3661 non-null   float64
#  8   Different_pct                3661 non-null   float64
#  9   Distinctive_pct              3661 non-null   float64
#  10  Unique_pct                   3661 non-null   float64
#  11  Dynamic_pct                  3661 non-null   float64
#  12  Innovative_pct               3661 non-null   float64
#  13  Leader_pct                   3661 non-null   float64
#  14  Reliable_pct                 3661 non-null   float64
#  15  High_quality_pct             3661 non-null   float64
#  16  Arrogant_pct                 3661 non-null   float64
#  17  Authentic_pct                3661 non-null   float64
#  18  Best_Brand_pct               3661 non-null   float64
#  19  Carefree_pct                 3661 non-null   float64
#  20  Cares_Customers_pct          3661 non-null   float64
#  21  Charming_pct                 3661 non-null   float64
#  22  Cool_pct                     3661 non-null   float64
#  23  Creative_pct                 3661 non-null   float64
#  24  Daring_pct                   3661 non-null   float64
#  25  Down_to_Earth_pct            3661 non-null   float64
#  26  Energetic_pct                3661 non-null   float64
#  27  Friendly_pct                 3661 non-null   float64
#  28  Fun_pct                      3661 non-null   float64
#  29  Gaining_In_Popularity_pct    3661 non-null   float64
#  30  Glamorous_pct                3661 non-null   float64
#  31  Good_Value_pct               3661 non-null   float64
#  32  Healthy_pct                  3661 non-null   float64
#  33  Helpful_pct                  3661 non-null   float64
#  34  High_Performance_pct         3661 non-null   float64
#  35  Independent_pct              3661 non-null   float64
#  36  Intelligent_pct              3661 non-null   float64
#  37  Kind_pct                     3661 non-null   float64
#  38  Original_pct                 3661 non-null   float64
#  39  Prestigious_pct              3661 non-null   float64
#  40  Progressive_pct              3661 non-null   float64
#  41  Rugged_pct                   3661 non-null   float64
#  42  Sensuous_pct                 3661 non-null   float64
#  43  Simple_pct                   3661 non-null   float64
#  44  Social_pct                   3661 non-null   float64
#  45  Socially_Responsible_pct     3661 non-null   float64
#  46  Straightforward_pct          3661 non-null   float64
#  47  Stylish_pct                  3661 non-null   float64
#  48  Traditional_pct              3661 non-null   float64
#  49  Trendy_pct                   3661 non-null   float64
#  50  Trustworthy_pct              3661 non-null   float64
#  51  Unapproachable_pct           3661 non-null   float64
#  52  Up_To_Date_pct               3661 non-null   float64
#  53  Upper_Class_pct              3661 non-null   float64
#  54  Visionary_pct                3661 non-null   float64
#  55  Worth_More_pct               3661 non-null   float64
#  56  company                      3661 non-null   object
#  57  ticker_symbol                1857 non-null   object
# dtypes: float64(55), object(3)
# memory usage: 1.6+ MB

# %%
BAV_2019_clean.describe()
# Out:
#        Recommend_to_a_friend_pct  Energized_Differentiation_C  Relevance_C  \
# count                3661.000000                  3661.000000  3661.000000
# mean                   11.489829                     0.599423     2.563751
# std                     8.511323                     0.121756     0.511106
# min                     0.000000                     0.311285     0.844490
# 25%                     5.298754                     0.512744     2.237851
# 50%                     9.159182                     0.582937     2.508065
# 75%                    15.871840                     0.667548     2.814287
# max                    50.524490                     1.298806     5.316035
#
#           Esteem_C  Knowledge_C  Brand_Stature_C  Brand_Strength_C  \
# count  3661.000000  3661.000000      3661.000000       3661.000000
# mean      0.469592     2.281783         1.216697          1.544480
# std       0.204010     1.151295         1.105876          0.473453
# min       0.040534     0.404155         0.060507          0.415449
# 25%       0.336072     1.232965         0.427885          1.220497
# 50%       0.416729     2.230872         0.843926          1.486404
# 75%       0.549660     3.177931         1.605285          1.798942
# max       1.729260     5.400015         9.338032          6.904500
#
#        Different_pct  Distinctive_pct   Unique_pct  ...  Straightforward_pct  \
# count    3661.000000      3661.000000  3661.000000  ...          3661.000000
# mean        9.667682        11.328327     9.828487  ...            10.510167
# std         2.566735         2.666646     2.634567  ...             2.242157
# min         3.170468         3.848764     3.395080  ...             2.463440
# 25%         7.758272         9.569076     7.957906  ...             9.008438
# 50%         9.214972        10.956990     9.430772  ...            10.359760
# 75%        11.198800        12.645950    11.298210  ...            11.848010
# max        24.764650        28.001511    27.185499  ...            26.774879
#
#        Stylish_pct  Traditional_pct   Trendy_pct  Trustworthy_pct  \
# count  3661.000000      3661.000000  3661.000000      3661.000000
# mean      8.074497        10.065465    12.360245        15.011998
# std       4.457644         3.942529     4.350993         5.094438
# min       1.510261         2.449850     2.655645         2.830153
# 25%       5.167236         7.388420     9.192031        11.343880
# 50%       6.616443         9.183610    11.598720        14.207090
# 75%       9.287068        11.752480    14.637160        17.949520
# max      30.094561        44.155819    31.842150        36.037380
#
#        Unapproachable_pct  Up_To_Date_pct  Upper_Class_pct  Visionary_pct  \
# count         3661.000000     3661.000000      3661.000000    3661.000000
# mean             5.599303       10.953085         8.134424      10.439582
# std              2.389911        2.697314         4.281554       3.229588
# min              0.000000        1.012154         0.646502       2.295802
# 25%              4.056057        9.142184         5.515210       8.229247
# 50%              5.047016       10.614800         6.940361       9.839184
# 75%              6.550036       12.445580         9.315038      12.030550
# max             28.341579       25.543341        38.324921      31.832420
#
#        Worth_More_pct
# count     3661.000000
# mean         6.280366
# std          2.498400
# min          0.000000
# 25%          4.501060
# 50%          5.842760
# 75%          7.563744
# max         17.525881
#
# [8 rows x 55 columns]

# %% [markdown]
# ### Create New DataFrame for Stock Data

# %%
stock_data = pd.DataFrame()
stock_data['ticker_symbol'] = BAV_2019_clean['ticker_symbol']

# %%
stock_data.head()
# Out:
#              ticker_symbol
# Company 2019
# Acura                  NaN
# Alfa Romeo             RMO
# Aston Martin           NaN
# Audi                   NaN
# Bentley                BSY

# %%
stock_data['total_shares'] = BAV_2019_clean['ticker_symbol'].apply(lambda x: None if x is np.NaN else get_number_of_shares(x))

# %%
stock_data.sample(10)
# Out:
#                   ticker_symbol
# Company 2019
# Hipmunk                     NaN
# Paychex                    PAYX
# JC Penney                   NaN
# Swanson                     NaN
# Estroven                    NaN
# Jif                         NaN
# Perdue                      NaN
# Pottery Barn                  B
# Thomas Keller               TBA
# Mountain Hardwear           IRM

# %%
# True is number of brands with a matched ticker symbol
stock_data['ticker_symbol'].notnull().value_counts()
# Out:
# True     1857
# False    1804
# Name: ticker_symbol, dtype: int64

# %%
# More than 1 indicates duplicate ticker symbol
stock_data['ticker_symbol'].sort_values(ascending=False).value_counts()
# Out:
# S        150
# COMS      51
# NEW       22
# GOOGL     20
# UVV       16
#         ...
# LOGI       1
# FMB        1
# CUI        1
# PACE       1
# TIF        1
# Name: ticker_symbol, Length: 870, dtype: int64

# %%
ore_ida = stock_data.loc[stock_data['ticker_symbol']=='IDA']
ore_ida
# Out:
#              ticker_symbol
# Company 2019
# Ore-Ida                IDA

# %% [markdown]
# #### Changing the Target Variable
# * Problem:
# >The ticker data is too sparce and inaccurate to be valuable. I know that I've matched a little more than 50% of the companies in the dataset, but of those, many are duplicates that will have to be dealt with. While that's all addressable, the biggest problem is the inacuracy: I can see from the sample of the dataframe above that the brand 'Ore-Ida' was matched as ticker IDA. I happen to know that Ore-Ida (the frozen potato brand) is part of the Kraft-Heinz company and should not have its own ticker symbol. A quick Google search verifies this issue (screenshot below).
#
# * Solution:
# >The working hypothesis to this point has been that market capitalization, or more specifically, the percentage delta in annual market capitalization, would be the ultimate target feature for prediction. Getting this specific feature cleanly into the dataframe in line with the other independent variables in the set has proven too inacurate programatically. To verify each of the companies individually would not be worth the effort. It's time to make a shift in the target variable.

# %%
display.Image("https://i.ibb.co/vLrf9TG/Screen-Shot-2021-04-12-at-4-27-37-AM.png")

# %% [markdown]
# ## Changing the Target Variable

# %% [markdown]
# ### Option B: 'Recommend to a Friend'

# %% [markdown]
# Let's start by taking a deeper look at this new target feature and then how our other survey response data is distributed.

# %%
BAV_2019_clean['Recommend_to_a_friend_pct'].describe()
# Out:
# count    3661.000000
# mean       11.489829
# std         8.511323
# min         0.000000
# 25%         5.298754
# 50%         9.159182
# 75%        15.871840
# max        50.524490
# Name: Recommend_to_a_friend_pct, dtype: float64

# %%
figure(figsize=(14, 8))
plt.hist(BAV_2019_clean['Recommend_to_a_friend_pct'])
plt.title("'Recommend to a Friend' Distribution")
plt.xlabel('Raw Score')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# With a tiny bit of cleaning, this looks like a good option. The min value (0.0) represents an absence of recomendations.
# Let's isolate those below and take a look at the specifically.

# %%
zero_recos_2019 = BAV_2019_clean.loc[BAV_2019_clean['Recommend_to_a_friend_pct']==0]
zero_recos_2018 = BAV_2018_clean.loc[BAV_2018_clean['Recommend_to_a_friend_pct']==0]
print(zero_recos_2019.shape[0])
# Out:
# 240

# %%
#Using color to see if zero recommendation (set to red) are distributed differently
figure(figsize=(14, 8))
plt.scatter(BAV_2019_clean['Esteem_C'], BAV_2019_clean['Relevance_C'], c=BAV_2019_clean['Recommend_to_a_friend_pct'].apply(lambda x: 'red' if x==0 else 'blue'), alpha=.5)
plt.title('Brand Esteem vs. Brand Relevance')
plt.xlabel('Esteem')
plt.ylabel('Relevance')
plt.show()

# %%
figure(figsize=(14, 8))
plt.scatter(BAV_2019_clean['Innovative_pct'], BAV_2019_clean['High_quality_pct'], c=BAV_2019_clean['Recommend_to_a_friend_pct'].apply(lambda x: 'red' if x==0 else 'blue'), alpha=.5)
plt.title('Brand Innovation vs. High Quality')
plt.xlabel('Innovation')
plt.ylabel('High Quality')
plt.show()

# %%
figure(figsize=(14, 8))
plt.scatter(BAV_2019_clean['Prestigious_pct'], BAV_2019_clean['Good_Value_pct'], c=BAV_2019_clean['Recommend_to_a_friend_pct'].apply(lambda x: 'red' if x==0 else 'blue'), alpha=.5)
plt.title('Brand Prestigious vs. Good Value')
plt.xlabel('Prestigious')
plt.ylabel('Good Value')
plt.show()

# %% [markdown]
# The abscence of recomendations doesn't appear to affect the data. Will keep these values in the dataset.

# %%
BAV_2019 = BAV_2019_clean
BAV_2018 = BAV_2018_clean

# %% [markdown]
# ### Merging the 2018 and 2019 Data

# %% [markdown]
# Start by dropping the stock data from the relevant columns

# %%
rel_cols = ['Recommend_to_a_friend_pct', 'Energized_Differentiation_C', 'Relevance_C', 'Esteem_C', 'Knowledge_C', 'Brand_Stature_C', 'Brand_Strength_C', 'Different_pct', 'Distinctive_pct', 'Unique_pct', 'Dynamic_pct', 'Innovative_pct', 'Leader_pct', 'Reliable_pct', 'High_quality_pct', 'Arrogant_pct', 'Authentic_pct', 'Best_Brand_pct', 'Carefree_pct', 'Cares_Customers_pct', 'Charming_pct', 'Cool_pct', 'Creative_pct', 'Daring_pct', 'Down_to_Earth_pct', 'Energetic_pct', 'Friendly_pct', 'Fun_pct', 'Gaining_In_Popularity_pct', 'Glamorous_pct', 'Good_Value_pct', 'Healthy_pct', 'Helpful_pct', 'High_Performance_pct', 'Independent_pct', 'Intelligent_pct', 'Kind_pct', 'Original_pct', 'Prestigious_pct', 'Progressive_pct', 'Rugged_pct', 'Sensuous_pct', 'Simple_pct', 'Social_pct', 'Socially_Responsible_pct', 'Straightforward_pct', 'Stylish_pct', 'Traditional_pct', 'Trendy_pct', 'Trustworthy_pct', 'Unapproachable_pct', 'Up_To_Date_pct', 'Upper_Class_pct', 'Visionary_pct', 'Worth_More_pct']
BAV_2018 = BAV_2018.drop(['Brand_ID', 'company', 'ticker_symbol'], axis=1)
BAV_2019 = BAV_2019.drop(['Brand_ID', 'company', 'ticker_symbol'], axis=1)
BAV_2019.head()
# Out:
#               Recommend_to_a_friend_pct  Energized_Differentiation_C  \
# Company 2019
# Acura                          9.953999                     0.642188
# Alfa Romeo                     4.776871                     0.762568
# Aston Martin                   5.559846                     0.850419
# Audi                           9.149771                     0.769728
# Bentley                        6.758671                     0.767631
#
#               Relevance_C  Esteem_C  Knowledge_C  Brand_Stature_C  \
# Company 2019
# Acura            2.139913  0.539018     3.184861         1.716698
# Alfa Romeo       1.758157  0.317809     2.082544         0.661852
# Aston Martin     1.654088  0.440287     2.108977         0.928555
# Audi             2.099322  0.567456     3.103108         1.760876
# Bentley          1.696136  0.482285     2.661824         1.283759
#
#               Brand_Strength_C  Different_pct  Distinctive_pct  Unique_pct  \
# Company 2019
# Acura                 1.374227       8.288108        13.685770    8.809677
# Alfa Romeo            1.340714       9.912714        17.094549   12.282400
# Aston Martin          1.406667      11.399390        19.736879   14.658690
# Audi                  1.615906       9.106336        16.300961   11.311780
# Bentley               1.302006      10.520440        18.429020   12.581550
#
#               ...  Straightforward_pct  Stylish_pct  Traditional_pct  \
# Company 2019  ...
# Acura         ...             9.458297    15.892970         8.759768
# Alfa Romeo    ...             8.145388    16.810770         7.273140
# Aston Martin  ...             7.946951    19.329081         7.312238
# Audi          ...             7.745929    21.346279         7.943208
# Bentley       ...             7.727577    17.727449        10.515710
#
#               Trendy_pct  Trustworthy_pct  Unapproachable_pct  Up_To_Date_pct  \
# Company 2019
# Acura           14.57190        16.129530            5.455859       11.924330
# Alfa Romeo      12.65383         8.988947            8.070658        9.083805
# Aston Martin    13.29794        11.300640           10.102460        9.896882
# Audi            15.87654        15.379080            6.150225       11.646320
# Bentley         11.63354        11.235060            9.541951        9.916174
#
#               Upper_Class_pct  Visionary_pct  Worth_More_pct
# Company 2019
# Acura               16.334471       12.20723        7.467402
# Alfa Romeo          24.738430       10.36332        7.162646
# Aston Martin        28.885571       11.90374        7.692444
# Audi                26.495449       11.09996        7.660220
# Bentley             35.123810       10.46475       10.152610
#
# [5 rows x 55 columns]

# %% [markdown]
# Now lets get both years into the same shape and matched on the index.

# %%
BAV_merge = pd.merge(BAV_2019, BAV_2018, left_index=True, right_index=True)
BAV_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3029 entries, Acura to Thomson Reuters
# Columns: 110 entries, Recommend_to_a_friend_pct_x to Worth_More_pct_y
# dtypes: float64(110)
# memory usage: 2.6+ MB

# %%
BAV_merge.head()
# Out:
#               Recommend_to_a_friend_pct_x  Energized_Differentiation_C_x  \
# Acura                            9.953999                       0.642188
# Alfa Romeo                       4.776871                       0.762568
# Aston Martin                     5.559846                       0.850419
# Audi                             9.149771                       0.769728
# Bentley                          6.758671                       0.767631
#
#               Relevance_C_x  Esteem_C_x  Knowledge_C_x  Brand_Stature_C_x  \
# Acura              2.139913    0.539018       3.184861           1.716698
# Alfa Romeo         1.758157    0.317809       2.082544           0.661852
# Aston Martin       1.654088    0.440287       2.108977           0.928555
# Audi               2.099322    0.567456       3.103108           1.760876
# Bentley            1.696136    0.482285       2.661824           1.283759
#
#               Brand_Strength_C_x  Different_pct_x  Distinctive_pct_x  \
# Acura                   1.374227         8.288108          13.685770
# Alfa Romeo              1.340714         9.912714          17.094549
# Aston Martin            1.406667        11.399390          19.736879
# Audi                    1.615906         9.106336          16.300961
# Bentley                 1.302006        10.520440          18.429020
#
#               Unique_pct_x  ...  Straightforward_pct_y  Stylish_pct_y  \
# Acura             8.809677  ...               8.849539      15.710160
# Alfa Romeo       12.282400  ...               6.080796      17.267210
# Aston Martin     14.658690  ...               6.469045      16.646311
# Audi             11.311780  ...              10.260040      18.800541
# Bentley          12.581550  ...               7.434486      19.569870
#
#               Traditional_pct_y  Trendy_pct_y  Trustworthy_pct_y  \
# Acura                  6.446314      14.55371          16.099440
# Alfa Romeo             7.225183      14.87083           9.865144
# Aston Martin           5.149739      12.15355           9.925730
# Audi                   8.386318      15.85582          12.400040
# Bentley               11.032830      12.52582          12.685470
#
#               Unapproachable_pct_y  Up_To_Date_pct_y  Upper_Class_pct_y  \
# Acura                     5.703656         11.032270          15.302950
# Alfa Romeo               10.311310         10.518590          25.941139
# Aston Martin              9.625601          7.878853          30.506660
# Audi                      6.730000         10.951970          21.809719
# Bentley                  11.473560          9.141562          34.941780
#
#               Visionary_pct_y  Worth_More_pct_y
# Acura               12.951940          6.352579
# Alfa Romeo           9.230522          8.130341
# Aston Martin        10.001760          8.295667
# Audi                11.357830          8.388798
# Bentley              9.720911         10.133530
#
# [5 rows x 110 columns]

# %%
# Split the dataframe so they can be referenced by single year
BAV_2019_clean = BAV_merge.iloc[:, 0:55]
BAV_2018_clean = BAV_merge.iloc[:, 55:]

# %%
# Ensure all remaining columns are strictly numerical
BAV_2019_clean.columns = rel_cols
BAV_2018_clean.columns = rel_cols
BAV_2019_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3029 entries, Acura to Thomson Reuters
# Data columns (total 55 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Recommend_to_a_friend_pct    3029 non-null   float64
#  1   Energized_Differentiation_C  3029 non-null   float64
#  2   Relevance_C                  3029 non-null   float64
#  3   Esteem_C                     3029 non-null   float64
#  4   Knowledge_C                  3029 non-null   float64
#  5   Brand_Stature_C              3029 non-null   float64
#  6   Brand_Strength_C             3029 non-null   float64
#  7   Different_pct                3029 non-null   float64
#  8   Distinctive_pct              3029 non-null   float64
#  9   Unique_pct                   3029 non-null   float64
#  10  Dynamic_pct                  3029 non-null   float64
#  11  Innovative_pct               3029 non-null   float64
#  12  Leader_pct                   3029 non-null   float64
#  13  Reliable_pct                 3029 non-null   float64
#  14  High_quality_pct             3029 non-null   float64
#  15  Arrogant_pct                 3029 non-null   float64
#  16  Authentic_pct                3029 non-null   float64
#  17  Best_Brand_pct               3029 non-null   float64
#  18  Carefree_pct                 3029 non-null   float64
#  19  Cares_Customers_pct          3029 non-null   float64
#  20  Charming_pct                 3029 non-null   float64
#  21  Cool_pct                     3029 non-null   float64
#  22  Creative_pct                 3029 non-null   float64
#  23  Daring_pct                   3029 non-null   float64
#  24  Down_to_Earth_pct            3029 non-null   float64
#  25  Energetic_pct                3029 non-null   float64
#  26  Friendly_pct                 3029 non-null   float64
#  27  Fun_pct                      3029 non-null   float64
#  28  Gaining_In_Popularity_pct    3029 non-null   float64
#  29  Glamorous_pct                3029 non-null   float64
#  30  Good_Value_pct               3029 non-null   float64
#  31  Healthy_pct                  3029 non-null   float64
#  32  Helpful_pct                  3029 non-null   float64
#  33  High_Performance_pct         3029 non-null   float64
#  34  Independent_pct              3029 non-null   float64
#  35  Intelligent_pct              3029 non-null   float64
#  36  Kind_pct                     3029 non-null   float64
#  37  Original_pct                 3029 non-null   float64
#  38  Prestigious_pct              3029 non-null   float64
#  39  Progressive_pct              3029 non-null   float64
#  40  Rugged_pct                   3029 non-null   float64
#  41  Sensuous_pct                 3029 non-null   float64
#  42  Simple_pct                   3029 non-null   float64
#  43  Social_pct                   3029 non-null   float64
#  44  Socially_Responsible_pct     3029 non-null   float64
#  45  Straightforward_pct          3029 non-null   float64
#  46  Stylish_pct                  3029 non-null   float64
#  47  Traditional_pct              3029 non-null   float64
#  48  Trendy_pct                   3029 non-null   float64
#  49  Trustworthy_pct              3029 non-null   float64
#  50  Unapproachable_pct           3029 non-null   float64
#  51  Up_To_Date_pct               3029 non-null   float64
#  52  Upper_Class_pct              3029 non-null   float64
#  53  Visionary_pct                3029 non-null   float64
#  54  Worth_More_pct               3029 non-null   float64
# dtypes: float64(55)
# memory usage: 1.3+ MB

# %%
BAV_2019_clean.describe()
# Out:
#        Recommend_to_a_friend_pct  Energized_Differentiation_C  Relevance_C  \
# count                3029.000000                  3029.000000  3029.000000
# mean                   12.227637                     0.592563     2.558670
# std                     8.642720                     0.119603     0.535758
# min                     0.000000                     0.311285     0.844490
# 25%                     5.906502                     0.508624     2.208778
# 50%                     9.951759                     0.577068     2.483519
# 75%                    16.778049                     0.655952     2.824780
# max                    50.524490                     1.298806     5.316035
#
#           Esteem_C  Knowledge_C  Brand_Stature_C  Brand_Strength_C  \
# count  3029.000000  3029.000000      3029.000000       3029.000000
# mean      0.480044     2.417067         1.309381          1.524549
# std       0.211464     1.130168         1.141725          0.483225
# min       0.040534     0.451745         0.094541          0.415449
# 25%       0.338744     1.413719         0.489027          1.199096
# 50%       0.422540     2.410630         0.945055          1.455168
# 75%       0.567161     3.291446         1.713484          1.766953
# max       1.729260     5.400015         9.338032          6.904500
#
#        Different_pct  Distinctive_pct   Unique_pct  ...  Straightforward_pct  \
# count    3029.000000      3029.000000  3029.000000  ...          3029.000000
# mean        9.453804        11.334386     9.667819  ...            10.481324
# std         2.435090         2.640911     2.547925  ...             2.171216
# min         3.170468         3.848764     3.395080  ...             3.729762
# 25%         7.639136         9.606853     7.878414  ...             9.007236
# 50%         9.011404        10.938380     9.261843  ...            10.328020
# 75%        10.842810        12.631660    11.029920  ...            11.818200
# max        23.264080        28.001511    27.185499  ...            24.433090
#
#        Stylish_pct  Traditional_pct   Trendy_pct  Trustworthy_pct  \
# count  3029.000000      3029.000000  3029.000000      3029.000000
# mean      8.017307        10.182407    12.266436        15.202157
# std       4.598054         4.033941     4.373238         5.190599
# min       1.510261         3.181672     3.591598         2.830153
# 25%       5.105659         7.403674     9.041631        11.445390
# 50%       6.421590         9.270680    11.480330        14.359220
# 75%       9.087747        11.898230    14.521630        18.293591
# max      30.094561        44.155819    31.842150        35.576180
#
#        Unapproachable_pct  Up_To_Date_pct  Upper_Class_pct  Visionary_pct  \
# count         3029.000000     3029.000000      3029.000000    3029.000000
# mean             5.455439       10.925308         8.084777      10.339806
# std              2.276615        2.684992         4.435503       3.231518
# min              0.000000        1.012154         0.777813       2.295802
# 25%              4.001856        9.113459         5.462269       8.143838
# 50%              4.939425       10.569450         6.764189       9.709717
# 75%              6.379164       12.377930         9.086181      11.852250
# max             27.709190       23.699970        38.324921      31.832420
#
#        Worth_More_pct
# count     3029.000000
# mean         6.319053
# std          2.534389
# min          0.563824
# 25%          4.486778
# 50%          5.851316
# 75%          7.648536
# max         17.525881
#
# [8 rows x 55 columns]

# %% [markdown]
# Target variable and dataframe is now all cleaned up and appears to be more consistently disributed Let's visualize this with some of the features. Aside from the '_C' columns, everything is nicely scaled.

# %%
#Summary Columns
stature_and_strength = ['Recommend_to_a_friend_pct', 'Brand_Stature_C', 'Brand_Strength_C']
summary_cols = ['Recommend_to_a_friend_pct', 'Energized_Differentiation_C', 'Relevance_C', 'Esteem_C', 'Knowledge_C']

# %% [markdown]
# ### Visualizations

# %%
#Pairplot of features
_ = sns.pairplot(BAV_2019_clean[summary_cols], diag_kind = 'kde')
plt.show()

# %% [markdown]
# There appears to be some good correlation happening with many of these features moving together. It's hard to tell with the scatterplots—let's draw some heat maps to get a better look.

# %%
plt.figure(figsize=(12, 18))
heatmap = sns.heatmap(BAV_2019_clean.corr()[['Recommend_to_a_friend_pct']].sort_values(by='Recommend_to_a_friend_pct', ascending=False))
heatmap.set_title('Features Correlating with Brand Recommentation')
plt.show()

# %%
corr.head()
# Out:
#                            Recommend_to_a_friend_pct  \
# Recommend_to_a_friend_pct                   1.000000
# Brand_Stature_C                             0.834567
# Knowledge_C                                 0.787632
# Esteem_C                                    0.724436
# Best_Brand_pct                              0.706233
#
#                            Energized_Differentiation_C  Relevance_C  Esteem_C  \
# Recommend_to_a_friend_pct                    -0.006806     0.697908  0.724436
# Brand_Stature_C                               0.063982     0.728599  0.922482
# Knowledge_C                                  -0.101052     0.459426  0.624013
# Esteem_C                                      0.153444     0.773295  1.000000
# Best_Brand_pct                                0.336309     0.702854  0.827520
#
#                            Knowledge_C  Brand_Stature_C  Brand_Strength_C  \
# Recommend_to_a_friend_pct     0.787632         0.834567          0.458780
# Brand_Stature_C               0.837272         1.000000          0.538905
# Knowledge_C                   1.000000         0.837272          0.247149
# Esteem_C                      0.624013         0.922482          0.619235
# Best_Brand_pct                0.557325         0.799589          0.696842
#
#                            Different_pct  Distinctive_pct  Unique_pct  ...  \
# Recommend_to_a_friend_pct      -0.199204         0.224732   -0.023731  ...
# Brand_Stature_C                -0.267832         0.306420   -0.033144  ...
# Knowledge_C                    -0.336033         0.213343   -0.125536  ...
# Esteem_C                       -0.225430         0.334278    0.013473  ...
# Best_Brand_pct                 -0.000313         0.485789    0.251339  ...
#
#                            Stylish_pct  Traditional_pct  Trendy_pct  \
# Recommend_to_a_friend_pct    -0.103385         0.461402   -0.008213
# Brand_Stature_C              -0.092899         0.575606   -0.114700
# Knowledge_C                  -0.137112         0.496838   -0.103167
# Esteem_C                     -0.048067         0.529915   -0.127623
# Best_Brand_pct                0.009386         0.478436    0.057069
#
#                            Trustworthy_pct  Unapproachable_pct  \
# Recommend_to_a_friend_pct         0.654700           -0.423724
# Brand_Stature_C                   0.784291           -0.291718
# Knowledge_C                       0.526739           -0.257662
# Esteem_C                          0.866709           -0.309228
# Best_Brand_pct                    0.683996           -0.221498
#
#                            Up_To_Date_pct  Upper_Class_pct  Visionary_pct  \
# Recommend_to_a_friend_pct        0.211142        -0.224731       0.080012
# Brand_Stature_C                  0.300837        -0.095718       0.271266
# Knowledge_C                      0.082261        -0.161400       0.064193
# Esteem_C                         0.409488        -0.016482       0.384459
# Best_Brand_pct                   0.351323         0.032474       0.356554
#
#                            Worth_More_pct  Year
# Recommend_to_a_friend_pct        0.586721   NaN
# Brand_Stature_C                  0.621480   NaN
# Knowledge_C                      0.368598   NaN
# Esteem_C                         0.715642   NaN
# Best_Brand_pct                   0.802016   NaN
#
# [5 rows x 56 columns]

# %%
plt.figure(figsize=(12, 12))
corr = BAV_2019_clean.corr().sort_values(by='Recommend_to_a_friend_pct', ascending=False)
# Reordering columns to in order of their correlation
corr_t = corr.T
BAV_sorted = BAV_2019_clean[corr_t.columns]
heatmap = sns.heatmap(BAV_sorted.corr().sort_values(by='Recommend_to_a_friend_pct', ascending=False))
heatmap.set_title('All Correlation')
plt.show()

# %% [markdown]
# There is a lot to take in here. When looking at what moves with the target variable, there are some features that rise to the top. The '_C' attributes of Esteem, Relevance, Knowledge and Stretgth rise to the top with some others like the perception of being 'Trustworthy', 'Original' and 'Down to Earth' playing a role as well. As well, attributes like 'Arrogance' and 'Unapproachable' could be good negative correlators for the model. In the middle it's pretty muddy and there's a lot of overlap. This can be seen in the eye-chart of the full correlation heat map. This will have to be addressed in the Feature Engineering phase. Potentially conducting a PCA to reduce or consolodate the number of features.

# %%
figure(figsize=(14, 8))
plt.scatter(BAV_2019['Worth_More_pct'], BAV_2019['Recommend_to_a_friend_pct'], alpha=.25)
plt.title('Worth More correlation with recommend to a friend')
plt.xlabel('Worth More')
plt.ylabel('Recommend to a Friend')
plt.show()

# %%
sns.jointplot(x=BAV_2019['Unapproachable_pct'], y=BAV_2019['Recommend_to_a_friend_pct'], kind='kde', height=14)
plt.title('Unapproachable correlation with recommend to a friend')
plt.show()

# %%
sns.jointplot(x=BAV_2019['Trustworthy_pct'], y=BAV_2019['Recommend_to_a_friend_pct'], kind ='kde', height=14)
plt.title('Trustworthy correlation with recommend to a friend')
plt.show()

# %%
sns.jointplot(x=BAV_2019['Innovative_pct'], y=BAV_2019['Recommend_to_a_friend_pct'], kind ='kde', height=14)
plt.title('Innovative correlation with recommend to a friend')
plt.show()

# %% [markdown]
# There are deffinitely some long-tail distributions for many of these attributes.
# While there are dense spots, it will be interesting to try to condence these features in the next phase.

# %% [markdown]
# ### Experiment

# %% [markdown]
# Before it's potentially lost, I'm curious to know how significant are the year over year changes? We know there has been a push across the board in brands attempting to build their perception around social responsibility. How did this attribute change between 2018 and 2019 in the eyes of consumers? Was this observed change significant or expected?

# %%
sr_2019 = pd.DataFrame(BAV_2019_clean['Socially_Responsible_pct'])
sr_2018 = pd.DataFrame(BAV_2018_clean['Socially_Responsible_pct'])
sr_2018['Year'] = 2018
sr_2019['Year'] = 2019

# %%
sr_join = pd.concat([sr_2018, sr_2019])
sr_join.sample(10)
# Out:
#                  Socially_Responsible_pct  Year
# State Farm                      11.831700  2019
# Related Rentals                 13.612020  2019
# Amazon Prime                    11.619910  2019
# Exide                            8.137265  2018
# Vans                             7.702953  2018
# NCIS                             7.883176  2018
# Coldwater Creek                  9.279142  2018
# Satin Care                      11.469200  2018
# Iran                             4.169163  2018
# Crest                           12.821820  2019

# %%
sr_join.boxplot(column='Socially_Responsible_pct', by='Year', figsize=(14, 8)) 
plt.ylabel('Raw Score')
plt.show()

# %%
sr_join.groupby('Year').describe()
# Out:
#      Socially_Responsible_pct                                          \
#                         count      mean       std       min       25%
# Year
# 2018                   3029.0  9.369408  2.645657  0.755704  7.813464
# 2019                   3029.0  9.464367  2.616389  2.777488  7.927513
#
#
#            50%       75%      max
# Year
# 2018  8.962921  10.33408  32.5998
# 2019  9.010865  10.34989  36.1012

# %% [markdown]
# ***Finding:*** Social Responsibility perception did rise across the board between 2018 and 2019. But is this change statistically significant?

# %%
# Cross Checking with the t-test function
from scipy import stats
t, p = stats.ttest_ind(BAV_2019_clean['Socially_Responsible_pct'], BAV_2018_clean['Socially_Responsible_pct'])
print("t = " + str(t))
print("p = " + str(p))
# Out:
# t = 1.4045504975156577
# p = 0.16020627111272698

# %% [markdown]
# ***Takeaway:*** The 2019 mean 'social responsibility' p-value is well above the .05 significance level. This attribute change for 2019 can be viewed as not statistically significant as this shows about a 16% likelihood of happening by chance.

# %% [markdown]
# ### Save Outs

# %%
BAV_2018 = pd.DataFrame(BAV_2018_clean)
BAV_2019 = pd.DataFrame(BAV_2019_clean)

BAV_2018['Year'] = 2018
BAV_2019['Year'] = 2019
BAV_join = pd.concat([BAV_2018, BAV_2019])

# %%
BAV_join.sample(5)
# Out:
#                             Recommend_to_a_friend_pct  \
# Rachael Ray Nutrish Just 6                   7.353264
# Mike`s hard lemonade                        14.574690
# CCM                                          4.349314
# Gorton`s                                    18.680080
# ROHL                                         4.456839
#
#                             Energized_Differentiation_C  Relevance_C  \
# Rachael Ray Nutrish Just 6                     0.545461     2.172080
# Mike`s hard lemonade                           0.522568     2.346019
# CCM                                            0.607224     2.587897
# Gorton`s                                       0.478353     3.042134
# ROHL                                           0.558771     2.298570
#
#                             Esteem_C  Knowledge_C  Brand_Stature_C  \
# Rachael Ray Nutrish Just 6  0.312054     2.056336         0.641688
# Mike`s hard lemonade        0.327487     2.919961         0.956248
# CCM                         0.344601     0.696097         0.239876
# Gorton`s                    0.636751     2.953830         1.880853
# ROHL                        0.373691     0.746759         0.279057
#
#                             Brand_Strength_C  Different_pct  Distinctive_pct  \
# Rachael Ray Nutrish Just 6          1.184786       9.569323         10.45166
# Mike`s hard lemonade                1.225954       7.485036         11.77743
# CCM                                 1.571433       8.431303         10.94206
# Gorton`s                            1.455215       8.672974         10.57926
# ROHL                                1.284375       7.395892         11.70535
#
#                             Unique_pct  ...  Stylish_pct  Traditional_pct  \
# Rachael Ray Nutrish Just 6    9.623226  ...     8.069784         8.498858
# Mike`s hard lemonade          7.798904  ...     4.926615         7.912172
# CCM                          13.628120  ...    10.234400        10.020860
# Gorton`s                      7.710305  ...     4.370436        14.953100
# ROHL                          8.977029  ...     8.743155         8.820431
#
#                             Trendy_pct  Trustworthy_pct  Unapproachable_pct  \
# Rachael Ray Nutrish Just 6   11.776350        14.202290            3.524755
# Mike`s hard lemonade         15.701960        12.248230            2.660247
# CCM                           8.637335        12.331140            7.706002
# Gorton`s                      8.935293        18.606501            4.293542
# ROHL                         12.454610        10.652890            4.615663
#
#                             Up_To_Date_pct  Upper_Class_pct  Visionary_pct  \
# Rachael Ray Nutrish Just 6        9.582428         6.943021       7.299120
# Mike`s hard lemonade              8.093093         4.684026       6.295352
# CCM                              11.120180         9.541300      10.701880
# Gorton`s                          9.657156         5.741467       7.121606
# ROHL                             12.294420         8.181166      10.992070
#
#                             Worth_More_pct  Year
# Rachael Ray Nutrish Just 6        5.961317  2019
# Mike`s hard lemonade              5.985717  2019
# CCM                               3.338560  2019
# Gorton`s                          7.017505  2018
# ROHL                              5.760624  2018
#
# [5 rows x 56 columns]

# %%
BAV_join.to_csv("../data/BAV_join.csv")
BAV_2018.to_csv("../data/BAV_2018_EDA.csv")
BAV_2019.to_csv("../data/BAV_2019_EDA.csv")

# %% [markdown]
# ### Next Steps

# %% [markdown]
# The data is ready to move on to the feature engineering stage. As there are still a large number of features (50+), the goal will be to look for ways to reduce the number before modeling. PCA should be explored.
