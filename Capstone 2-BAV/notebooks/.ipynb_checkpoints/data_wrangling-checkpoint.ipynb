# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import requests
import numpy as np
import time

import yfinance as yf
from pandas_datareader import data as pdr

# %% [markdown]
# ### 1. Load Brand Data from excel files (BAV)

# %%
# Load the first XLS data file in the raw_data directory
BAV_2017 = pd.read_excel('../raw_data/USA-All-Adults-2017.xls', header=0, index_col=0)

# %%
BAV_2017.head()
# Out:
#                                                    Brand_ID  Dupl_Index  \
# USA - Adults 2017 Full Year All Adults Holdout....
# Acura                                                  AVE            0
# Alfa Romeo                                             CQK            0
# Aston Martin                                           MKU            0
# Audi                                                   AAA            0
# Bentley                                                MLA            0
#
#                                                    Category_CD  Category_NM  \
# USA - Adults 2017 Full Year All Adults Holdout....
# Acura                                                      A01  Automobiles
# Alfa Romeo                                                 A01  Automobiles
# Aston Martin                                               A01  Automobiles
# Audi                                                       A01  Automobiles
# Bentley                                                    A01  Automobiles
#
#                                                    Sector   Brand_Base  \
# USA - Adults 2017 Full Year All Adults Holdout....
# Acura                                                Auto  1203.781982
# Alfa Romeo                                           Auto   873.028198
# Aston Martin                                         Auto   999.520020
# Audi                                                 Auto  1123.498047
# Bentley                                              Auto  1032.130005
#
#                                                     Unweighted_Brand_Base  \
# USA - Adults 2017 Full Year All Adults Holdout....
# Acura                                                                1218
# Alfa Romeo                                                            879
# Aston Martin                                                         1016
# Audi                                                                 1156
# Bentley                                                              1020
#
#                                                     Energized_Differentiation_R  \
# USA - Adults 2017 Full Year All Adults Holdout....
# Acura                                                                 49.463009
# Alfa Romeo                                                            93.227921
# Aston Martin                                                          94.779243
# Audi                                                                  92.034607
# Bentley                                                               92.482101
#
#                                                     Relevance_R   Esteem_R  \
# USA - Adults 2017 Full Year All Adults Holdout....
# Acura                                                 12.082340  71.062050
# Alfa Romeo                                             1.581146  23.508350
# Aston Martin                                           1.372315  44.122910
# Audi                                                   9.218377  73.657516
# Bentley                                                1.968974  64.797127
#
#                                                     ...  \
# USA - Adults 2017 Full Year All Adults Holdout....  ...
# Acura                                               ...
# Alfa Romeo                                          ...
# Aston Martin                                        ...
# Audi                                                ...
# Bentley                                             ...
#
#                                                     Treatment_Understand_C  \
# USA - Adults 2017 Full Year All Adults Holdout....
# Acura                                                                    0
# Alfa Romeo                                                               0
# Aston Martin                                                             0
# Audi                                                                     0
# Bentley                                                                  0
#
#                                                     Top_of_Mind_pct  \
# USA - Adults 2017 Full Year All Adults Holdout....
# Acura                                                           NaN
# Alfa Romeo                                                      NaN
# Aston Martin                                                    NaN
# Audi                                                            NaN
# Bentley                                                         NaN
#
#                                                     Total_Unaided_pct  Wave  \
# USA - Adults 2017 Full Year All Adults Holdout....
# Acura                                                             NaN   NaN
# Alfa Romeo                                                        NaN   NaN
# Aston Martin                                                      NaN   NaN
# Audi                                                              NaN   NaN
# Bentley                                                           NaN   NaN
#
#                                                     Year  Country  Brand_Key  \
# USA - Adults 2017 Full Year All Adults Holdout....
# Acura                                                NaN      NaN        551
# Alfa Romeo                                           NaN      NaN       1779
# Aston Martin                                         NaN      NaN       8496
# Audi                                                 NaN      NaN          1
# Bentley                                              NaN      NaN       8502
#
#                                                     Category_Key  BaseID  \
# USA - Adults 2017 Full Year All Adults Holdout....
# Acura                                                          5  243576
# Alfa Romeo                                                     5  243576
# Aston Martin                                                   5  243576
# Audi                                                           5  243576
# Bentley                                                        5  243576
#
#                                                     BSS_ID
# USA - Adults 2017 Full Year All Adults Holdout....
# Acura                                               296225
# Alfa Romeo                                          296225
# Aston Martin                                        296225
# Audi                                                296225
# Bentley                                             296225
#
# [5 rows x 180 columns]

# %%
# Load the two additional XLS data files
BAV_2018 = pd.read_excel('../raw_data/USA-All-Adults-2018.xls', header=0, index_col=0)
BAV_2019 = pd.read_excel('../raw_data/USA-All-Adults-2019.xls', header=0, index_col=0)

# %%
BAV_2018.head()
# Out:
#                                                    Brand_ID  Dupl_Index  \
# USA - Adults 2018 Full Year All Adults Holdout....
# Acura                                                  AVE            0
# Alfa Romeo                                             CQK            0
# Aston Martin                                           MKU            0
# Audi                                                   AAA            0
# Bentley                                                MLA            0
#
#                                                    Category_CD  Category_NM  \
# USA - Adults 2018 Full Year All Adults Holdout....
# Acura                                                      A01  Automobiles
# Alfa Romeo                                                 A01  Automobiles
# Aston Martin                                               A01  Automobiles
# Audi                                                       A01  Automobiles
# Bentley                                                    A01  Automobiles
#
#                                                    Sector   Brand_Base  \
# USA - Adults 2018 Full Year All Adults Holdout....
# Acura                                                Auto  1314.562012
# Alfa Romeo                                           Auto   942.608582
# Aston Martin                                         Auto  1040.751953
# Audi                                                 Auto  1257.609009
# Bentley                                              Auto  1187.797974
#
#                                                     Unweighted_Brand_Base  \
# USA - Adults 2018 Full Year All Adults Holdout....
# Acura                                                                1328
# Alfa Romeo                                                            961
# Aston Martin                                                         1065
# Audi                                                                 1262
# Bentley                                                              1178
#
#                                                     Energized_Differentiation_R  \
# USA - Adults 2018 Full Year All Adults Holdout....
# Acura                                                                 59.728287
# Alfa Romeo                                                            94.080544
# Aston Martin                                                          94.323143
# Audi                                                                  94.226105
# Bentley                                                               94.808342
#
#                                                     Relevance_R   Esteem_R  \
# USA - Adults 2018 Full Year All Adults Holdout....
# Acura                                                 20.912178  71.858322
# Alfa Romeo                                             2.134886  27.947598
# Aston Martin                                           1.407084  26.880156
# Audi                                                  11.159631  71.615723
# Bentley                                                1.746725  66.909264
#
#                                                     ...  \
# USA - Adults 2018 Full Year All Adults Holdout....  ...
# Acura                                               ...
# Alfa Romeo                                          ...
# Aston Martin                                        ...
# Audi                                                ...
# Bentley                                             ...
#
#                                                     Treatment_Understand_C  \
# USA - Adults 2018 Full Year All Adults Holdout....
# Acura                                                                    0
# Alfa Romeo                                                               0
# Aston Martin                                                             0
# Audi                                                                     0
# Bentley                                                                  0
#
#                                                     Top_of_Mind_pct  \
# USA - Adults 2018 Full Year All Adults Holdout....
# Acura                                                           NaN
# Alfa Romeo                                                      NaN
# Aston Martin                                                    NaN
# Audi                                                            NaN
# Bentley                                                         NaN
#
#                                                     Total_Unaided_pct  Wave  \
# USA - Adults 2018 Full Year All Adults Holdout....
# Acura                                                             NaN   NaN
# Alfa Romeo                                                        NaN   NaN
# Aston Martin                                                      NaN   NaN
# Audi                                                              NaN   NaN
# Bentley                                                           NaN   NaN
#
#                                                     Year  Country  Brand_Key  \
# USA - Adults 2018 Full Year All Adults Holdout....
# Acura                                                NaN      NaN        551
# Alfa Romeo                                           NaN      NaN       1779
# Aston Martin                                         NaN      NaN       8496
# Audi                                                 NaN      NaN          1
# Bentley                                              NaN      NaN       8502
#
#                                                     Category_Key  BaseID  \
# USA - Adults 2018 Full Year All Adults Holdout....
# Acura                                                          5  258039
# Alfa Romeo                                                     5  258039
# Aston Martin                                                   5  258039
# Audi                                                           5  258039
# Bentley                                                        5  258039
#
#                                                     BSS_ID
# USA - Adults 2018 Full Year All Adults Holdout....
# Acura                                               314828
# Alfa Romeo                                          314828
# Aston Martin                                        314828
# Audi                                                314828
# Bentley                                             314828
#
# [5 rows x 184 columns]

# %%
BAV_2019.head()
# Out:
#                                                    Brand_ID  Dupl_Index  \
# USA - Adults 2019 Full Year All Adults Holdout....
# Acura                                                  AVE            0
# Alfa Romeo                                             CQK            0
# Aston Martin                                           MKU            0
# Audi                                                   AAA            0
# Bentley                                                MLA            0
#
#                                                    Category_CD  Category_NM  \
# USA - Adults 2019 Full Year All Adults Holdout....
# Acura                                                      A01  Automobiles
# Alfa Romeo                                                 A01  Automobiles
# Aston Martin                                               A01  Automobiles
# Audi                                                       A01  Automobiles
# Bentley                                                    A01  Automobiles
#
#                                                    Sector   Brand_Base  \
# USA - Adults 2019 Full Year All Adults Holdout....
# Acura                                                Auto  1160.282959
# Alfa Romeo                                           Auto   912.620789
# Aston Martin                                         Auto   916.633179
# Audi                                                 Auto  1161.255005
# Bentley                                              Auto  1147.734985
#
#                                                     Unweighted_Brand_Base  \
# USA - Adults 2019 Full Year All Adults Holdout....
# Acura                                                                1192
# Alfa Romeo                                                            927
# Aston Martin                                                          918
# Audi                                                                 1198
# Bentley                                                              1150
#
#                                                     Energized_Differentiation_R  \
# USA - Adults 2019 Full Year All Adults Holdout....
# Acura                                                                 72.705315
# Alfa Romeo                                                            91.980675
# Aston Martin                                                          97.101448
# Audi                                                                  92.801933
# Bentley                                                               92.463768
#
#                                                     Relevance_R   Esteem_R  \
# USA - Adults 2019 Full Year All Adults Holdout....
# Acura                                                 19.082125  71.545891
# Alfa Romeo                                             3.574879  17.681160
# Aston Martin                                           2.125604  52.705315
# Audi                                                  16.038647  75.072464
# Bentley                                                2.608696  61.787441
#
#                                                     ...  \
# USA - Adults 2019 Full Year All Adults Holdout....  ...
# Acura                                               ...
# Alfa Romeo                                          ...
# Aston Martin                                        ...
# Audi                                                ...
# Bentley                                             ...
#
#                                                     Treatment_Understand_C  \
# USA - Adults 2019 Full Year All Adults Holdout....
# Acura                                                                    0
# Alfa Romeo                                                               0
# Aston Martin                                                             0
# Audi                                                                     0
# Bentley                                                                  0
#
#                                                     Top_of_Mind_pct  \
# USA - Adults 2019 Full Year All Adults Holdout....
# Acura                                                           NaN
# Alfa Romeo                                                      NaN
# Aston Martin                                                    NaN
# Audi                                                            NaN
# Bentley                                                         NaN
#
#                                                     Total_Unaided_pct  Wave  \
# USA - Adults 2019 Full Year All Adults Holdout....
# Acura                                                             NaN   NaN
# Alfa Romeo                                                        NaN   NaN
# Aston Martin                                                      NaN   NaN
# Audi                                                              NaN   NaN
# Bentley                                                           NaN   NaN
#
#                                                     Year  Country  Brand_Key  \
# USA - Adults 2019 Full Year All Adults Holdout....
# Acura                                                NaN      NaN        551
# Alfa Romeo                                           NaN      NaN       1779
# Aston Martin                                         NaN      NaN       8496
# Audi                                                 NaN      NaN          1
# Bentley                                              NaN      NaN       8502
#
#                                                     Category_Key  BaseID  \
# USA - Adults 2019 Full Year All Adults Holdout....
# Acura                                                          5  268911
# Alfa Romeo                                                     5  268911
# Aston Martin                                                   5  268911
# Audi                                                           5  268911
# Bentley                                                        5  268911
#
#                                                     BSS_ID
# USA - Adults 2019 Full Year All Adults Holdout....
# Acura                                               329227
# Alfa Romeo                                          329227
# Aston Martin                                        329227
# Audi                                                329227
# Bentley                                             329227
#
# [5 rows x 184 columns]

# %%
BAV_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3766 entries, Acura to Gogo Inflight
# Columns: 184 entries, Brand_ID to BSS_ID
# dtypes: float64(151), int64(29), object(4)
# memory usage: 5.3+ MB

# %% [markdown]
# May be helpful to exclude 2017. If the columns/brand attributes changed in 2018, focus the analysis on the consistent attributes in 2018 and 2019.

# %% [markdown]
# ### 2. Explore the Brand Data

# %%
BAV_2019[BAV_2019.index == 'Acura'].transpose()
# Out:
# USA - Adults 2019 Full Year All Adults Holdout. Base size 12412(12707.2)        Acura
# Brand_ID                                                                         AVE
# Dupl_Index                                                                          0
# Category_CD                                                                       A01
# Category_NM                                                               Automobiles
# Sector                                                                           Auto
# ...                                                                               ...
# Country                                                                           NaN
# Brand_Key                                                                         551
# Category_Key                                                                        5
# BaseID                                                                         268911
# BSS_ID                                                                         329227
#
# [184 rows x 1 columns]

# %%
BAV_2019[BAV_2019.index == 'Acura'].columns
# Out:
# Index(['Brand_ID', 'Dupl_Index', 'Category_CD', 'Category_NM', 'Sector',
#        'Brand_Base', 'Unweighted_Brand_Base', 'Energized_Differentiation_R',
#        'Relevance_R', 'Esteem_R',
#        ...
#        'Treatment_Understand_C', 'Top_of_Mind_pct', 'Total_Unaided_pct',
#        'Wave', 'Year', 'Country', 'Brand_Key', 'Category_Key', 'BaseID',
#        'BSS_ID'],
#       dtype='object', length=184)

# %%
BAV_2018[BAV_2018.index == 'Acura'].columns
# Out:
# Index(['Brand_ID', 'Dupl_Index', 'Category_CD', 'Category_NM', 'Sector',
#        'Brand_Base', 'Unweighted_Brand_Base', 'Energized_Differentiation_R',
#        'Relevance_R', 'Esteem_R',
#        ...
#        'Treatment_Understand_C', 'Top_of_Mind_pct', 'Total_Unaided_pct',
#        'Wave', 'Year', 'Country', 'Brand_Key', 'Category_Key', 'BaseID',
#        'BSS_ID'],
#       dtype='object', length=184)

# %% [markdown]
# BAV Data appears to be consistent between 2018 and 2019.
# Will confirm with more validation before next phase.
# Moving on to Financial Data Import.

# %% [markdown]
# ### 3. Import Financial Data from Yahoo Finance (fin)

# %% [markdown]
# 1. Will need to use the yf API to bring in financial data from the same periods (2018, 2019)
# 2. Join companies/brands based on name

# %%
#test the connection
fin = yf.download(
        tickers = "AAPL MSFT",
        period = "2y",
        interval = "3mo",
        group_by = 'ticker')
# Out:
# [*********************100%***********************]  2 of 2 completed

# %%
fin.AAPL.info
# Out:
# <bound method DataFrame.info of                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-03-01   43.570000   53.827499   42.375000   43.767502   42.869724
# 2019-05-10         NaN         NaN         NaN         NaN         NaN
# 2019-05-15         NaN         NaN         NaN         NaN         NaN
# 2019-06-01   43.900002   55.342499   42.567501   52.185001   51.311405
# 2019-08-09         NaN         NaN         NaN         NaN         NaN
# 2019-08-14         NaN         NaN         NaN         NaN         NaN
# 2019-09-01   51.607498   67.000000   51.055000   66.812500   65.943619
# 2019-11-07         NaN         NaN         NaN         NaN         NaN
# 2019-11-20         NaN         NaN         NaN         NaN         NaN
# 2019-12-01   66.817497   81.962502   64.072502   68.339996   67.653778
# 2020-02-07         NaN         NaN         NaN         NaN         NaN
# 2020-02-19         NaN         NaN         NaN         NaN         NaN
# 2020-03-01   70.570000   81.059998   53.152500   79.485001   78.873604
# 2020-05-08         NaN         NaN         NaN         NaN         NaN
# 2020-05-20         NaN         NaN         NaN         NaN         NaN
# 2020-06-01   79.437500  131.000000   79.302498  129.039993  128.394058
# 2020-08-07         NaN         NaN         NaN         NaN         NaN
# 2020-08-19         NaN         NaN         NaN         NaN         NaN
# 2020-08-31         NaN         NaN         NaN         NaN         NaN
# 2020-09-01  132.759995  137.979996  103.099998  119.050003  118.667633
# 2020-11-06         NaN         NaN         NaN         NaN         NaN
# 2020-11-18         NaN         NaN         NaN         NaN         NaN
# 2020-12-01  121.010002  145.089996  118.389999  121.260002  121.079071
# 2021-02-05         NaN         NaN         NaN         NaN         NaN
# 2021-02-17         NaN         NaN         NaN         NaN         NaN
# 2021-03-01  123.750000  127.745003  122.790001  127.540100  127.540100
#
#                   Volume
# Date
# 2019-03-01  7.586223e+09
# 2019-05-10           NaN
# 2019-05-15           NaN
# 2019-06-01  6.680608e+09
# 2019-08-09           NaN
# 2019-08-14           NaN
# 2019-09-01  6.396805e+09
# 2019-11-07           NaN
# 2019-11-20           NaN
# 2019-12-01  8.343016e+09
# 2020-02-07           NaN
# 2020-02-19           NaN
# 2020-03-01  1.235260e+10
# 2020-05-08           NaN
# 2020-05-20           NaN
# 2020-06-01  1.033449e+10
# 2020-08-07           NaN
# 2020-08-19           NaN
# 2020-08-31           NaN
# 2020-09-01  8.903861e+09
# 2020-11-06           NaN
# 2020-11-18           NaN
# 2020-12-01  6.394009e+09
# 2021-02-05           NaN
# 2021-02-17           NaN
# 2021-03-01  9.720735e+07  >

# %%
fin.AAPL
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-03-01   43.570000   53.827499   42.375000   43.767502   42.869724
# 2019-05-10         NaN         NaN         NaN         NaN         NaN
# 2019-05-15         NaN         NaN         NaN         NaN         NaN
# 2019-06-01   43.900002   55.342499   42.567501   52.185001   51.311405
# 2019-08-09         NaN         NaN         NaN         NaN         NaN
# 2019-08-14         NaN         NaN         NaN         NaN         NaN
# 2019-09-01   51.607498   67.000000   51.055000   66.812500   65.943619
# 2019-11-07         NaN         NaN         NaN         NaN         NaN
# 2019-11-20         NaN         NaN         NaN         NaN         NaN
# 2019-12-01   66.817497   81.962502   64.072502   68.339996   67.653778
# 2020-02-07         NaN         NaN         NaN         NaN         NaN
# 2020-02-19         NaN         NaN         NaN         NaN         NaN
# 2020-03-01   70.570000   81.059998   53.152500   79.485001   78.873604
# 2020-05-08         NaN         NaN         NaN         NaN         NaN
# 2020-05-20         NaN         NaN         NaN         NaN         NaN
# 2020-06-01   79.437500  131.000000   79.302498  129.039993  128.394058
# 2020-08-07         NaN         NaN         NaN         NaN         NaN
# 2020-08-19         NaN         NaN         NaN         NaN         NaN
# 2020-08-31         NaN         NaN         NaN         NaN         NaN
# 2020-09-01  132.759995  137.979996  103.099998  119.050003  118.667633
# 2020-11-06         NaN         NaN         NaN         NaN         NaN
# 2020-11-18         NaN         NaN         NaN         NaN         NaN
# 2020-12-01  121.010002  145.089996  118.389999  121.260002  121.079071
# 2021-02-05         NaN         NaN         NaN         NaN         NaN
# 2021-02-17         NaN         NaN         NaN         NaN         NaN
# 2021-03-01  123.750000  127.745003  122.790001  127.540100  127.540100
#
#                   Volume
# Date
# 2019-03-01  7.586223e+09
# 2019-05-10           NaN
# 2019-05-15           NaN
# 2019-06-01  6.680608e+09
# 2019-08-09           NaN
# 2019-08-14           NaN
# 2019-09-01  6.396805e+09
# 2019-11-07           NaN
# 2019-11-20           NaN
# 2019-12-01  8.343016e+09
# 2020-02-07           NaN
# 2020-02-19           NaN
# 2020-03-01  1.235260e+10
# 2020-05-08           NaN
# 2020-05-20           NaN
# 2020-06-01  1.033449e+10
# 2020-08-07           NaN
# 2020-08-19           NaN
# 2020-08-31           NaN
# 2020-09-01  8.903861e+09
# 2020-11-06           NaN
# 2020-11-18           NaN
# 2020-12-01  6.394009e+09
# 2021-02-05           NaN
# 2021-02-17           NaN
# 2021-03-01  9.720735e+07

# %% [markdown]
# ***Result:*** Seems like the right API to use. Will park this thought for now and focus on wrangling the brand data for 2018 and 2019.

# %% [markdown]
# ### 4. Now for the ticker symbol lookup

# %% [markdown]
# Using this API to lookup the company by name. Including API key in the URL so can be run in notebook: http://www.polygon.io
# -Then wrapping it in a convenience function.

# %%
lookup_url = 'https://api.polygon.io/v2/reference/tickers?sort=ticker&perpage=3&page=1&apiKey=znY3_peGnZRXAcpXCeW3i2UVdCKz28Bq&search='
major_exchanges = ['NYE', 'NASDAQ']

def get_ticker_for(company_name):
    query = lookup_url + str(company_name)
    response = requests.get(query)
    data = response.json()
    if not data['tickers']:
        time.sleep(.1) # Slight pause every few calls so API doesn't timeout
        return None
    elif data['tickers']:
        for ticker in data['tickers']:
            try:
                if ticker['primaryExch'] in major_exchanges:
                    return ticker['ticker']
                else:
                    continue
            except:
                continue

# %%
#test with Tesla (one word query)
get_ticker_for(BAV_2019.index[32])
# Out:
# 'TSLA'

# %%
#and Dr. Pepper (multiple word query)
get_ticker_for(BAV_2019.index[108])
# Out:
# 'KDP'

# %%
print(len(BAV_2019))
# Out:
# 3766

# %%
#Add column company as index value
BAV_2019['company'] = BAV_2019.index
BAV_2018['company'] = BAV_2018.index

BAV_2019.index.rename('company_2019', inplace=True)
BAV_2018.index.rename('company_2018', inplace=True)

# %% [markdown]
# ### 5. Match Ticker Symbols with Brand Data Frames

# %%
BAV_2019['ticker_symbol'] = BAV_2019['company'].apply(lambda x: get_ticker_for(x))

# %%
BAV_2018['ticker_symbol'] = BAV_2018['company'].apply(lambda x: get_ticker_for(x))

# %% [markdown]
# Above cells will each take a few minutes to populate (28 min on 2013 macbook pro)

# %%
BAV_2019.head()
# Out:
#              Brand_ID  Dupl_Index Category_CD  Category_NM Sector  \
# company_2019
# Acura            AVE            0         A01  Automobiles   Auto
# Alfa Romeo       CQK            0         A01  Automobiles   Auto
# Aston Martin     MKU            0         A01  Automobiles   Auto
# Audi             AAA            0         A01  Automobiles   Auto
# Bentley          MLA            0         A01  Automobiles   Auto
#
#                Brand_Base  Unweighted_Brand_Base  Energized_Differentiation_R  \
# company_2019
# Acura         1160.282959                   1192                    72.705315
# Alfa Romeo     912.620789                    927                    91.980675
# Aston Martin   916.633179                    918                    97.101448
# Audi          1161.255005                   1198                    92.801933
# Bentley       1147.734985                   1150                    92.463768
#
#               Relevance_R   Esteem_R  ...  Total_Unaided_pct  Wave  Year  \
# company_2019                          ...
# Acura           19.082125  71.545891  ...                NaN   NaN   NaN
# Alfa Romeo       3.574879  17.681160  ...                NaN   NaN   NaN
# Aston Martin     2.125604  52.705315  ...                NaN   NaN   NaN
# Audi            16.038647  75.072464  ...                NaN   NaN   NaN
# Bentley          2.608696  61.787441  ...                NaN   NaN   NaN
#
#               Country  Brand_Key  Category_Key  BaseID  BSS_ID       company  \
# company_2019
# Acura             NaN        551             5  268911  329227         Acura
# Alfa Romeo        NaN       1779             5  268911  329227    Alfa Romeo
# Aston Martin      NaN       8496             5  268911  329227  Aston Martin
# Audi              NaN          1             5  268911  329227          Audi
# Bentley           NaN       8502             5  268911  329227       Bentley
#
#               ticker_symbol
# company_2019
# Acura                  None
# Alfa Romeo              RMO
# Aston Martin           None
# Audi                   None
# Bentley                 BSY
#
# [5 rows x 186 columns]

# %%
BAV_2018.head()
# Out:
#              Brand_ID  Dupl_Index Category_CD  Category_NM Sector  \
# company_2018
# Acura            AVE            0         A01  Automobiles   Auto
# Alfa Romeo       CQK            0         A01  Automobiles   Auto
# Aston Martin     MKU            0         A01  Automobiles   Auto
# Audi             AAA            0         A01  Automobiles   Auto
# Bentley          MLA            0         A01  Automobiles   Auto
#
#                Brand_Base  Unweighted_Brand_Base  Energized_Differentiation_R  \
# company_2018
# Acura         1314.562012                   1328                    59.728287
# Alfa Romeo     942.608582                    961                    94.080544
# Aston Martin  1040.751953                   1065                    94.323143
# Audi          1257.609009                   1262                    94.226105
# Bentley       1187.797974                   1178                    94.808342
#
#               Relevance_R   Esteem_R  ...  Total_Unaided_pct  Wave  Year  \
# company_2018                          ...
# Acura           20.912178  71.858322  ...                NaN   NaN   NaN
# Alfa Romeo       2.134886  27.947598  ...                NaN   NaN   NaN
# Aston Martin     1.407084  26.880156  ...                NaN   NaN   NaN
# Audi            11.159631  71.615723  ...                NaN   NaN   NaN
# Bentley          1.746725  66.909264  ...                NaN   NaN   NaN
#
#               Country  Brand_Key  Category_Key  BaseID  BSS_ID       company  \
# company_2018
# Acura             NaN        551             5  258039  314828         Acura
# Alfa Romeo        NaN       1779             5  258039  314828    Alfa Romeo
# Aston Martin      NaN       8496             5  258039  314828  Aston Martin
# Audi              NaN          1             5  258039  314828          Audi
# Bentley           NaN       8502             5  258039  314828       Bentley
#
#               ticker_symbol
# company_2018
# Acura                  None
# Alfa Romeo              RMO
# Aston Martin           None
# Audi                   None
# Bentley                 BSY
#
# [5 rows x 186 columns]

# %%
#Matches out of 3766
BAV_years = [BAV_2018, BAV_2019]
for year in BAV_years:
    match_count = len(year['ticker_symbol'].unique())
    match_percentage = match_count/(len(year))*100
    
    print(match_count)
    print(match_percentage)
# Out:
# 855
# 23.476112026359143
# 871
# 23.127987254381306

# %%
#keeping this list handy for easy printouts
summary_columns = ['Sector', 'Relevance_R', 'Esteem_R', 'Knowledge_R',
       'Brand_Stature_R', 'Brand_Strength_R', 'ticker_symbol']

#want _R for percentile scores
relevant_columns = ['Relevance_R', 'Esteem_R', 'Knowledge_R',
       'Brand_Stature_R', 'Brand_Strength_R', 'Different_R',
       'Distinctive_R', 'Unique_R', 'Dynamic_R', 'Innovative_R',
       'Leader_R', 'Reliable_R', 'High_Quality_R', 'Arrogant_R',
       'Authentic_R', 'Best_Brand_R', 'Carefree_R',
       'Cares_Customers_R', 'Charming_R', 'Cool_R', 'Creative_R',
       'Daring_R', 'Down_To_Earth_R', 'Energetic_R', 'Friendly_R',
       'Fun_R', 'Gaining_in_Popularity_R', 'Glamorous_R',
       'Good_Value_R', 'Healthy_R', 'Helpful_R', 'High_Performance_R',
       'Independent_R', 'Intelligent_R', 'Kind_R',
       'Original_R', 'Prestigious_R', 'Progressive_R',
       'Rugged_R', 'Sensuous_R', 'Simple_R', 'Social_R',
       'Socially_Responsible_R', 'Straightforward_R', 'Stylish_R',
       'Traditional_R', 'Trendy_R', 'Trustworthy_R',
       'Unapproachable_R', 'Up_To_Date_R', 'Upper_Class_R',
       'Visionary_R', 'Worth_More_R', 'ticker_symbol']

#percentile scores w/o ticker symbols
numerical_columns = ['Relevance_R', 'Esteem_R', 'Knowledge_R',
       'Brand_Stature_R', 'Brand_Strength_R', 'Different_R',
       'Distinctive_R', 'Unique_R', 'Dynamic_R', 'Innovative_R',
       'Leader_R', 'Reliable_R', 'High_Quality_R', 'Arrogant_R',
       'Authentic_R', 'Best_Brand_R', 'Carefree_R',
       'Cares_Customers_R', 'Charming_R', 'Cool_R', 'Creative_R',
       'Daring_R', 'Down_To_Earth_R', 'Energetic_R', 'Friendly_R',
       'Fun_R', 'Gaining_in_Popularity_R', 'Glamorous_R',
       'Good_Value_R', 'Healthy_R', 'Helpful_R', 'High_Performance_R',
       'Independent_R', 'Intelligent_R', 'Kind_R', 'Obliging_R',
       'Original_R', 'Prestigious_R', 'Progressive_R', 'Restrained_R',
       'Rugged_R', 'Sensuous_R', 'Simple_R', 'Social_R',
       'Socially_Responsible_R', 'Straightforward_R', 'Stylish_R',
       'Traditional_R', 'Trendy_R', 'Trustworthy_R',
       'Unapproachable_R', 'Up_To_Date_R', 'Upper_Class_R',
       'Visionary_R', 'Worth_More_R']

# %%
#Raname Index for each year
BAV_2018.index.rename('Company 2018', inplace=True)
BAV_2019.index.rename('Company 2019', inplace=True)

# %%
print(BAV_2019.loc[['Chrysler', 'Tesla']][summary_columns])
# Out:
#              Sector  Relevance_R   Esteem_R  Knowledge_R  Brand_Stature_R  \
# Company 2019
# Chrysler       Auto    45.942028  68.067635    86.908211        78.405800
# Tesla          Auto     7.584541  71.449272    59.033817        68.212563
#
#               Brand_Strength_R ticker_symbol
# Company 2019
# Chrysler             48.309177          FCAM
# Tesla                92.463768          TSLA

# %%
print(BAV_2018.loc[['Chrysler', 'Tesla']][summary_columns])
# Out:
#              Sector  Relevance_R   Esteem_R  Knowledge_R  Brand_Stature_R  \
# Company 2018
# Chrysler       Auto    33.867054  67.394470    88.791847        78.360016
# Tesla          Auto     7.229500  72.925766    57.156719        67.637070
#
#               Brand_Strength_R ticker_symbol
# Company 2018
# Chrysler             45.608929          FCAM
# Tesla                92.819023          TSLA

# %% [markdown]
# More cleaning will have to be done, as many of the tickers are inacurate. For now, we know they match up. Saving and commiting the file to avoid rerunning.

# %% [markdown]
# ### 6. Handle Missing Values

# %%
missing_2019 = pd.concat([BAV_2019.isnull().sum(), 100 * BAV_2019.isnull().mean()], axis=1)
missing_2019.columns=['missing_count_2019', '%']
missing_2019.sort_values(by='missing_count_2019', ascending=False)
# Out:
#                    missing_count_2019      %
# Country                          3766  100.0
# Year                             3766  100.0
# Wave                             3766  100.0
# Total_Unaided_pct                3766  100.0
# Top_of_Mind_pct                  3766  100.0
# ...                               ...    ...
# Prestigious_pct                     0    0.0
# Progressive_pct                     0    0.0
# Restrained_pct                      0    0.0
# Rugged_pct                          0    0.0
# Carefree_R                          0    0.0
#
# [186 rows x 2 columns]

# %%
print(missing_2019.loc[summary_columns])
# Out:
#                   missing_count_2019          %
# Sector                             0   0.000000
# Relevance_R                        0   0.000000
# Esteem_R                           0   0.000000
# Knowledge_R                        0   0.000000
# Brand_Stature_R                    0   0.000000
# Brand_Strength_R                   0   0.000000
# ticker_symbol                   1844  48.964418

# %%
print(missing_2019.loc[relevant_columns])
# Out:
#                          missing_count_2019          %
# Relevance_R                               0   0.000000
# Esteem_R                                  0   0.000000
# Knowledge_R                               0   0.000000
# Brand_Stature_R                           0   0.000000
# Brand_Strength_R                          0   0.000000
# Different_R                               0   0.000000
# Distinctive_R                             0   0.000000
# Unique_R                                  0   0.000000
# Dynamic_R                                 0   0.000000
# Innovative_R                              0   0.000000
# Leader_R                                  0   0.000000
# Reliable_R                                0   0.000000
# High_Quality_R                            0   0.000000
# Arrogant_R                                0   0.000000
# Authentic_R                               0   0.000000
# Best_Brand_R                              0   0.000000
# Carefree_R                                0   0.000000
# Cares_Customers_R                         0   0.000000
# Charming_R                                0   0.000000
# Cool_R                                    0   0.000000
# Creative_R                                0   0.000000
# Daring_R                                  0   0.000000
# Down_To_Earth_R                           0   0.000000
# Energetic_R                               0   0.000000
# Friendly_R                                0   0.000000
# Fun_R                                     0   0.000000
# Gaining_in_Popularity_R                   0   0.000000
# Glamorous_R                               0   0.000000
# Good_Value_R                              0   0.000000
# Healthy_R                                 0   0.000000
# Helpful_R                                 0   0.000000
# High_Performance_R                        0   0.000000
# Independent_R                             0   0.000000
# Intelligent_R                             0   0.000000
# Kind_R                                    0   0.000000
# Obliging_R                                0   0.000000
# Original_R                                0   0.000000
# Prestigious_R                             0   0.000000
# Progressive_R                             0   0.000000
# Restrained_R                              0   0.000000
# Rugged_R                                  0   0.000000
# Sensuous_R                                0   0.000000
# Simple_R                                  0   0.000000
# Social_R                                  0   0.000000
# Socially_Responsible_R                    0   0.000000
# Straightforward_R                         0   0.000000
# Stylish_R                                 0   0.000000
# Traditional_R                             0   0.000000
# Trendy_R                                  0   0.000000
# Trustworthy_R                             0   0.000000
# Unapproachable_R                          0   0.000000
# Up_To_Date_R                              0   0.000000
# Upper_Class_R                             0   0.000000
# Visionary_R                               0   0.000000
# Worth_More_R                              0   0.000000
# ticker_symbol                          1844  48.964418

# %%
missing_2018 = pd.concat([BAV_2018.isnull().sum(), 100 * BAV_2018.isnull().mean()], axis=1)
missing_2018.columns=['missing_count_2018', '%']
missing_2018.sort_values(by='missing_count_2018', ascending=False)
# Out:
#                    missing_count_2018      %
# Country                          3642  100.0
# Year                             3642  100.0
# Wave                             3642  100.0
# Total_Unaided_pct                3642  100.0
# Top_of_Mind_pct                  3642  100.0
# ...                               ...    ...
# Progressive_pct                     0    0.0
# Restrained_pct                      0    0.0
# Rugged_pct                          0    0.0
# Sensuous_pct                        0    0.0
# Carefree_R                          0    0.0
#
# [186 rows x 2 columns]

# %%
print(missing_2018.loc[summary_columns])
# Out:
#                   missing_count_2018          %
# Sector                             2   0.054915
# Relevance_R                        0   0.000000
# Esteem_R                           0   0.000000
# Knowledge_R                        0   0.000000
# Brand_Stature_R                    0   0.000000
# Brand_Strength_R                   0   0.000000
# ticker_symbol                   1724  47.336628

# %%
print(missing_2018.loc[relevant_columns])
# Out:
#                          missing_count_2018          %
# Relevance_R                               0   0.000000
# Esteem_R                                  0   0.000000
# Knowledge_R                               0   0.000000
# Brand_Stature_R                           0   0.000000
# Brand_Strength_R                          0   0.000000
# Different_R                               0   0.000000
# Distinctive_R                             0   0.000000
# Unique_R                                  0   0.000000
# Dynamic_R                                 0   0.000000
# Innovative_R                              0   0.000000
# Leader_R                                  0   0.000000
# Reliable_R                                0   0.000000
# High_Quality_R                            0   0.000000
# Arrogant_R                                0   0.000000
# Authentic_R                               0   0.000000
# Best_Brand_R                              0   0.000000
# Carefree_R                                0   0.000000
# Cares_Customers_R                         0   0.000000
# Charming_R                                0   0.000000
# Cool_R                                    0   0.000000
# Creative_R                                0   0.000000
# Daring_R                                  0   0.000000
# Down_To_Earth_R                           0   0.000000
# Energetic_R                               0   0.000000
# Friendly_R                                0   0.000000
# Fun_R                                     0   0.000000
# Gaining_in_Popularity_R                   0   0.000000
# Glamorous_R                               0   0.000000
# Good_Value_R                              0   0.000000
# Healthy_R                                 0   0.000000
# Helpful_R                                 0   0.000000
# High_Performance_R                        0   0.000000
# Independent_R                             0   0.000000
# Intelligent_R                             0   0.000000
# Kind_R                                    0   0.000000
# Obliging_R                                0   0.000000
# Original_R                                0   0.000000
# Prestigious_R                             0   0.000000
# Progressive_R                             0   0.000000
# Restrained_R                              0   0.000000
# Rugged_R                                  0   0.000000
# Sensuous_R                                0   0.000000
# Simple_R                                  0   0.000000
# Social_R                                  0   0.000000
# Socially_Responsible_R                    0   0.000000
# Straightforward_R                         0   0.000000
# Stylish_R                                 0   0.000000
# Traditional_R                             0   0.000000
# Trendy_R                                  0   0.000000
# Trustworthy_R                             0   0.000000
# Unapproachable_R                          0   0.000000
# Up_To_Date_R                              0   0.000000
# Upper_Class_R                             0   0.000000
# Visionary_R                               0   0.000000
# Worth_More_R                              0   0.000000
# ticker_symbol                          1724  47.336628

# %% [markdown]
# ***Finding:*** Other than the ticker symbols, none of the relevant columns have missing vaues. Good news. A couple of sector values are missing in the 2018 set that can likely be imputed if necessary.

# %%
BAV_2019.select_dtypes('object')
# Out:
#                 Brand_ID Category_CD             Category_NM  \
# Company 2019
# Acura               AVE          A01             Automobiles
# Alfa Romeo          CQK          A01             Automobiles
# Aston Martin        MKU          A01             Automobiles
# Audi                AAA          A01             Automobiles
# Bentley             MLA          A01             Automobiles
# ...                  ...         ...                     ...
# Thomson Reuters     WMKF        Z99d   Financial Information
# UltraFICO           BMAX        Z99d   Financial Information
# FlightAware         BLTI        Z99j  Airline Internet Tools
# FlightView          BLTJ        Z99j  Airline Internet Tools
# Gogo Inflight       BLTK        Z99j  Airline Internet Tools
#
#                                                 Sector          company  \
# Company 2019
# Acura                                             Auto            Acura
# Alfa Romeo                                        Auto       Alfa Romeo
# Aston Martin                                      Auto     Aston Martin
# Audi                                              Auto             Audi
# Bentley                                           Auto          Bentley
# ...                                                ...              ...
# Thomson Reuters  Financial Services, Insurance & Banks  Thomson Reuters
# UltraFICO        Financial Services, Insurance & Banks        UltraFICO
# FlightAware                     Travel & Entertainment      FlightAware
# FlightView                      Travel & Entertainment       FlightView
# Gogo Inflight                   Travel & Entertainment    Gogo Inflight
#
#                 ticker_symbol
# Company 2019
# Acura                    None
# Alfa Romeo                RMO
# Aston Martin             None
# Audi                     None
# Bentley                   BSY
# ...                       ...
# Thomson Reuters           TRI
# UltraFICO                None
# FlightAware              None
# FlightView               None
# Gogo Inflight            GOGO
#
# [3766 rows x 6 columns]

# %%
BAV_2019['ticker_symbol'].value_counts().head(325)
# Out:
# S        158
# COMS      51
# NEW       23
# GOOGL     21
# FARM      19
#         ...
# MET        2
# RBS        2
# XM         2
# CCRC       1
# BWACU      1
# Name: ticker_symbol, Length: 325, dtype: int64

# %%
len(BAV_2019['ticker_symbol'].unique())
# Out:
# 871

# %%
BAV_2018.select_dtypes('object')
# Out:
#                 Brand_ID Category_CD            Category_NM  \
# Company 2018
# Acura               AVE          A01            Automobiles
# Alfa Romeo          CQK          A01            Automobiles
# Aston Martin        MKU          A01            Automobiles
# Audi                AAA          A01            Automobiles
# Bentley             MLA          A01            Automobiles
# ...                  ...         ...                    ...
# FactSet             BDCK        Z99d  Financial Information
# FICO                WODP        Z99d  Financial Information
# LifeLock            BDCU        Z99d  Financial Information
# Quicken             BEJ         Z99d  Financial Information
# Thomson Reuters     WMKF        Z99d  Financial Information
#
#                                                 Sector          company  \
# Company 2018
# Acura                                             Auto            Acura
# Alfa Romeo                                        Auto       Alfa Romeo
# Aston Martin                                      Auto     Aston Martin
# Audi                                              Auto             Audi
# Bentley                                           Auto          Bentley
# ...                                                ...              ...
# FactSet          Financial Services, Insurance & Banks          FactSet
# FICO             Financial Services, Insurance & Banks             FICO
# LifeLock         Financial Services, Insurance & Banks         LifeLock
# Quicken          Financial Services, Insurance & Banks          Quicken
# Thomson Reuters  Financial Services, Insurance & Banks  Thomson Reuters
#
#                 ticker_symbol
# Company 2018
# Acura                    None
# Alfa Romeo                RMO
# Aston Martin             None
# Audi                     None
# Bentley                   BSY
# ...                       ...
# FactSet                   FDS
# FICO                     FICO
# LifeLock                 None
# Quicken                  None
# Thomson Reuters           TRI
#
# [3642 rows x 6 columns]

# %%
BAV_2018['ticker_symbol'].value_counts().head(320)
# Out:
# S        160
# COMS      64
# NEW       23
# GOOGL     19
# LIVE      17
#         ...
# MIST       2
# AET        2
# PGRE       1
# NVS        1
# CAH        1
# Name: ticker_symbol, Length: 320, dtype: int64

# %%
len(BAV_2018['ticker_symbol'].unique())
# Out:
# 855

# %% [markdown]
# ***Problem:*** there are over 320 entries with duplicate ticker values. Since these should all be unique, these will have to be handled before analysis.

# %% [markdown]
# Since these are percentile figures, no numerical values should be over 100

# %%
BAV_2019[numerical_columns].max()
# Out:
# Relevance_R                100.000000
# Esteem_R                   100.000000
# Knowledge_R                100.000000
# Brand_Stature_R            100.000000
# Brand_Strength_R           100.000000
# Different_R                100.000000
# Distinctive_R              100.000000
# Unique_R                   100.000000
# Dynamic_R                  100.000000
# Innovative_R               100.000000
# Leader_R                   100.000000
# Reliable_R                 100.000000
# High_Quality_R              99.951691
# Arrogant_R                 100.000000
# Authentic_R                100.000000
# Best_Brand_R               100.000000
# Carefree_R                 100.000000
# Cares_Customers_R          100.000000
# Charming_R                 100.000000
# Cool_R                     100.000000
# Creative_R                 100.000000
# Daring_R                   100.000000
# Down_To_Earth_R            100.000000
# Energetic_R                100.000000
# Friendly_R                 100.000000
# Fun_R                      100.000000
# Gaining_in_Popularity_R    100.000000
# Glamorous_R                100.000000
# Good_Value_R               100.000000
# Healthy_R                  100.000000
# Helpful_R                  100.000000
# High_Performance_R         100.000000
# Independent_R              100.000000
# Intelligent_R              100.000000
# Kind_R                     100.000000
# Obliging_R                   0.048309
# Original_R                 100.000000
# Prestigious_R              100.000000
# Progressive_R              100.000000
# Restrained_R                 0.048309
# Rugged_R                   100.000000
# Sensuous_R                  99.951691
# Simple_R                   100.000000
# Social_R                   100.000000
# Socially_Responsible_R     100.000000
# Straightforward_R          100.000000
# Stylish_R                   99.951691
# Traditional_R              100.000000
# Trendy_R                   100.000000
# Trustworthy_R              100.000000
# Unapproachable_R           100.000000
# Up_To_Date_R               100.000000
# Upper_Class_R              100.000000
# Visionary_R                100.000000
# Worth_More_R               100.000000
# dtype: float64

# %%
BAV_2018[numerical_columns].max()
# Out:
# Relevance_R                100.000000
# Esteem_R                   100.000000
# Knowledge_R                100.000000
# Brand_Stature_R            100.000000
# Brand_Strength_R           100.000000
# Different_R                100.000000
# Distinctive_R              100.000000
# Unique_R                   100.000000
# Dynamic_R                  100.000000
# Innovative_R               100.000000
# Leader_R                   100.000000
# Reliable_R                 100.000000
# High_Quality_R              99.951477
# Arrogant_R                 100.000000
# Authentic_R                100.000000
# Best_Brand_R               100.000000
# Carefree_R                 100.000000
# Cares_Customers_R          100.000000
# Charming_R                 100.000000
# Cool_R                     100.000000
# Creative_R                 100.000000
# Daring_R                   100.000000
# Down_To_Earth_R            100.000000
# Energetic_R                100.000000
# Friendly_R                 100.000000
# Fun_R                      100.000000
# Gaining_in_Popularity_R    100.000000
# Glamorous_R                100.000000
# Good_Value_R               100.000000
# Healthy_R                  100.000000
# Helpful_R                  100.000000
# High_Performance_R         100.000000
# Independent_R              100.000000
# Intelligent_R              100.000000
# Kind_R                     100.000000
# Obliging_R                 100.000000
# Original_R                 100.000000
# Prestigious_R              100.000000
# Progressive_R              100.000000
# Restrained_R               100.000000
# Rugged_R                   100.000000
# Sensuous_R                  99.951477
# Simple_R                   100.000000
# Social_R                   100.000000
# Socially_Responsible_R     100.000000
# Straightforward_R          100.000000
# Stylish_R                   99.951477
# Traditional_R              100.000000
# Trendy_R                    99.951477
# Trustworthy_R              100.000000
# Unapproachable_R           100.000000
# Up_To_Date_R               100.000000
# Upper_Class_R              100.000000
# Visionary_R                100.000000
# Worth_More_R                99.951477
# dtype: float64

# %%
#A couple of values above stand out.
#Will be good to explore the disribution of these
#High Quality as an example and Obliging_R as one of the two that stand out as very low for a max score.

BAV_2019['High_Quality_R'].hist(bins=20)
plt.xlabel('High Quality Percentile')
plt.ylabel('Count')
plt.title('Distribution of High Quality Attribute 2019');

# %%
BAV_2019['Obliging_R'].hist(bins=20)
plt.xlabel('Obliging Percentile')
plt.ylabel('Count')
plt.title('Distribution of Obliging Attribute 2019');

# %% [markdown]
# ***Finding:*** An e-mail to the team resulted in a quick explanation. Two attributes (Obliging and Restrained) were replaced in 2018 to 'Cool' and 'Creative'. The relic attributes were retained in the set to help with historic analyses. Since we're focused on 2018 forward, these relic columns can be dropped from both years.

# %%
del BAV_2019['Obliging_R']
del BAV_2019['Restrained_R']

# %%
del BAV_2018['Obliging_R']
del BAV_2018['Restrained_R']

# %%
#Make sure the two data frames still match up
print(len(BAV_2019.columns))
# Out:
# 184

# %%
print(len(BAV_2018.columns))
# Out:
# 184

# %% [markdown]
# ### 7. Duplicate Companies

# %% [markdown]
# Some of the companies are present in multiple categories. There is a 'duplicate_index' column with a value of 1 to identify these. A 1 is present for each duplicated value only.

# %%
duplicate_companies_2019 = BAV_2019[BAV_2019['Dupl_Index'] == 1]
duplicate_companies_2018 = BAV_2018[BAV_2018['Dupl_Index'] == 1]

# %% [markdown]
# Noticed some whitespace in some of the brand IDs. Next we'll trim the whitespace on all IDs to clean up.

# %%
BAV_2019['Brand_ID'] = BAV_2019['Brand_ID'].str.strip()
BAV_2018['Brand_ID'] = BAV_2018['Brand_ID'].str.strip()

# %%
#Finding companies with more than 1 duplicate value
sorted_dups = duplicate_companies_2019.groupby("Brand_ID")['Dupl_Index'].sum()
sorted_dups = sorted_dups.sort_values(axis='index', ascending=False)
print(sorted_dups)
# Out:
# Brand_ID
# WJZD    2
# AHK     2
# YQRV    2
# AAI     1
# NKG     1
#        ..
# BDMI    1
# BDCV    1
# BCU     1
# BBYT    1
# YXSH    1
# Name: Dupl_Index, Length: 102, dtype: int64

# %%
BAV_2019[BAV_2019['Brand_ID'] == 'WJZD']
# Out:
#              Brand_ID  Dupl_Index Category_CD  \
# Company 2019
# Under Armour     WJZD           0         C17
# Under Armour     WJZD           1        S01g
# Under Armour     WJZD           1        YPAT
#
#                                       Category_NM                 Sector  \
# Company 2019
# Under Armour         Athleisure/Athletic Clothing  Apparel & Accessories
# Under Armour                       Athletic Shoes  Apparel & Accessories
# Under Armour  Extreme Sports Clothing & Equipment                 Sports
#
#                Brand_Base  Unweighted_Brand_Base  Energized_Differentiation_R  \
# Company 2019
# Under Armour  3527.096924                   3493                    96.038651
# Under Armour  3527.096924                   3493                    96.038651
# Under Armour  3527.096924                   3493                    96.038651
#
#               Relevance_R   Esteem_R  ...  Total_Unaided_pct  Wave  Year  \
# Company 2019                          ...
# Under Armour    86.328499  92.995171  ...                NaN   NaN   NaN
# Under Armour    86.328499  92.995171  ...                NaN   NaN   NaN
# Under Armour    86.328499  92.995171  ...                NaN   NaN   NaN
#
#               Country  Brand_Key  Category_Key  BaseID  BSS_ID       company  \
# Company 2019
# Under Armour      NaN     -22391           641  268911  329227  Under Armour
# Under Armour      NaN     -22391           747  268911  329227  Under Armour
# Under Armour      NaN     -22391         26160  268911  329227  Under Armour
#
#               ticker_symbol
# Company 2019
# Under Armour            UAA
# Under Armour            UAA
# Under Armour            UAA
#
# [3 rows x 184 columns]

# %%
BAV_2019[BAV_2019['Brand_ID'] == 'AHK']
# Out:
#              Brand_ID  Dupl_Index Category_CD                    Category_NM  \
# Company 2019
# Nabisco           AHK           0         F10                        Cereals
# Nabisco           AHK           1         F22  Cookies & Biscuits (Crackers)
# Nabisco           AHK           1         I01       Consumer Goods Companies
#
#                     Sector   Brand_Base  Unweighted_Brand_Base  \
# Company 2019
# Nabisco               Food  3748.606934                   3823
# Nabisco               Food  3748.606934                   3823
# Nabisco       Corporations  3748.606934                   3823
#
#               Energized_Differentiation_R  Relevance_R   Esteem_R  ...  \
# Company 2019                                                       ...
# Nabisco                         31.690821    98.309181  96.714973  ...
# Nabisco                         31.690821    98.309181  96.714973  ...
# Nabisco                         31.690821    98.309181  96.714973  ...
#
#               Total_Unaided_pct  Wave  Year  Country  Brand_Key  Category_Key  \
# Company 2019
# Nabisco                     NaN   NaN   NaN      NaN        193            22
# Nabisco                     NaN   NaN   NaN      NaN        193            40
# Nabisco                     NaN   NaN   NaN      NaN        193            39
#
#               BaseID  BSS_ID  company  ticker_symbol
# Company 2019
# Nabisco       268911  329227  Nabisco           None
# Nabisco       268911  329227  Nabisco           None
# Nabisco       268911  329227  Nabisco           None
#
# [3 rows x 184 columns]

# %%
BAV_2019[BAV_2019['Brand_ID'] == 'YQRV']
# Out:
#              Brand_ID  Dupl_Index Category_CD  \
# Company 2019
# Newman`s Own     YQRV           1         F07
# Newman`s Own     YQRV           1        F09d
# Newman`s Own     YQRV           0         I01
#
#                                                     Category_NM        Sector  \
# Company 2019
# Newman`s Own  Ready-made Sauces such as Pasta & Barbecue Sauces          Food
# Newman`s Own                                      Salsas & Dips          Food
# Newman`s Own                           Consumer Goods Companies  Corporations
#
#               Brand_Base  Unweighted_Brand_Base  Energized_Differentiation_R  \
# Company 2019
# Newman`s Own  3263.38501                   3355                    81.932365
# Newman`s Own  3263.38501                   3355                    81.932365
# Newman`s Own  3263.38501                   3355                    81.932365
#
#               Relevance_R   Esteem_R  ...  Total_Unaided_pct  Wave  Year  \
# Company 2019                          ...
# Newman`s Own    83.478264  82.125603  ...                NaN   NaN   NaN
# Newman`s Own    83.478264  82.125603  ...                NaN   NaN   NaN
# Newman`s Own    83.478264  82.125603  ...                NaN   NaN   NaN
#
#               Country  Brand_Key  Category_Key  BaseID  BSS_ID       company  \
# Company 2019
# Newman`s Own      NaN      23920           110  268911  329227  Newman`s Own
# Newman`s Own      NaN      23920         26735  268911  329227  Newman`s Own
# Newman`s Own      NaN      23920            39  268911  329227  Newman`s Own
#
#               ticker_symbol
# Company 2019
# Newman`s Own              S
# Newman`s Own              S
# Newman`s Own              S
#
# [3 rows x 184 columns]

# %% [markdown]
# Appears as though these are in fact duplicate rows. The category plays no role in the attribute values. There is no problem dropping these duplicates (Anything with a 1 in the 'Dupl_Index' column, as 0 is the first occurance).

# %%
BAV_2019_clean = BAV_2019[~BAV_2019.index.duplicated()]

# %%
#Verify they're removed
#Test on YQRV
BAV_2019_clean[BAV_2019_clean['Brand_ID'] == 'YQRV']
# Out:
#              Brand_ID  Dupl_Index Category_CD  \
# Company 2019
# Newman`s Own     YQRV           1         F07
#
#                                                     Category_NM Sector  \
# Company 2019
# Newman`s Own  Ready-made Sauces such as Pasta & Barbecue Sauces   Food
#
#               Brand_Base  Unweighted_Brand_Base  Energized_Differentiation_R  \
# Company 2019
# Newman`s Own  3263.38501                   3355                    81.932365
#
#               Relevance_R   Esteem_R  ...  Total_Unaided_pct  Wave  Year  \
# Company 2019                          ...
# Newman`s Own    83.478264  82.125603  ...                NaN   NaN   NaN
#
#               Country  Brand_Key  Category_Key  BaseID  BSS_ID       company  \
# Company 2019
# Newman`s Own      NaN      23920           110  268911  329227  Newman`s Own
#
#               ticker_symbol
# Company 2019
# Newman`s Own              S
#
# [1 rows x 184 columns]

# %%
#Finding companies with more than 1 duplicate value
sorted_dups = duplicate_companies_2018.groupby("Brand_ID")['Dupl_Index'].sum()
sorted_dups = sorted_dups.sort_values(axis='index', ascending=False)
print(sorted_dups)
# Out:
# Brand_ID
# SBN     2
# WJZD    2
# YQRV    2
# AHK     2
# AAI     1
#        ..
# BBYT    1
# BBN     1
# BBG     1
# BBEK    1
# YXSH    1
# Name: Dupl_Index, Length: 117, dtype: int64

# %%
BAV_2018[BAV_2018['Brand_ID'] == 'SBN']
# Out:
#                     Brand_ID  Dupl_Index Category_CD  \
# Company 2018
# Casper (Mattresses)      SBN           1        H22a
# Casper                   SBN           1         H24
# Casper                   SBN           0         R03
#
#                                                Category_NM  \
# Company 2018
# Casper (Mattresses)                             Mattresses
# Casper                                         Home Design
# Casper               Specialty Retail Stores - Home/Office
#
#                                   Sector  Brand_Base  Unweighted_Brand_Base  \
# Company 2018
# Casper (Mattresses)        Home & Garden  856.065674                    850
# Casper                     Home & Garden  856.065674                    850
# Casper               Distribution/Retail  856.065674                    850
#
#                      Energized_Differentiation_R  Relevance_R   Esteem_R  ...  \
# Company 2018                                                              ...
# Casper (Mattresses)                    89.810768    23.726347  29.500242  ...
# Casper                                 89.810768    23.726347  29.500242  ...
# Casper                                 89.810768    23.726347  29.500242  ...
#
#                      Total_Unaided_pct  Wave  Year  Country  Brand_Key  \
# Company 2018
# Casper (Mattresses)                NaN   NaN   NaN      NaN      13069
# Casper                             NaN   NaN   NaN      NaN      13069
# Casper                             NaN   NaN   NaN      NaN      13069
#
#                      Category_Key  BaseID  BSS_ID              company  \
# Company 2018
# Casper (Mattresses)         27085  258039  314828  Casper (Mattresses)
# Casper                      26714  258039  314828               Casper
# Casper                        122  258039  314828               Casper
#
#                      ticker_symbol
# Company 2018
# Casper (Mattresses)           CSPR
# Casper                        CSPR
# Casper                        CSPR
#
# [3 rows x 184 columns]

# %%
BAV_2018[BAV_2018['Brand_ID'] == 'YQRV']
# Out:
#              Brand_ID  Dupl_Index Category_CD  \
# Company 2018
# Newman`s Own     YQRV           1         F07
# Newman`s Own     YQRV           1        F09d
# Newman`s Own     YQRV           0         I01
#
#                                                     Category_NM        Sector  \
# Company 2018
# Newman`s Own  Ready-made Sauces such as Pasta & Barbecue Sauces          Food
# Newman`s Own                                             Salsas          Food
# Newman`s Own                           Consumer Goods Companies  Corporations
#
#                Brand_Base  Unweighted_Brand_Base  Energized_Differentiation_R  \
# Company 2018
# Newman`s Own  3430.964111                   3513                    73.410965
# Newman`s Own  3430.964111                   3513                    73.410965
# Newman`s Own  3430.964111                   3513                    73.410965
#
#               Relevance_R   Esteem_R  ...  Total_Unaided_pct  Wave  Year  \
# Company 2018                          ...
# Newman`s Own    83.794273  82.629791  ...                NaN   NaN   NaN
# Newman`s Own    83.794273  82.629791  ...                NaN   NaN   NaN
# Newman`s Own    83.794273  82.629791  ...                NaN   NaN   NaN
#
#               Country  Brand_Key  Category_Key  BaseID  BSS_ID       company  \
# Company 2018
# Newman`s Own      NaN      23920           110  258039  314828  Newman`s Own
# Newman`s Own      NaN      23920         26735  258039  314828  Newman`s Own
# Newman`s Own      NaN      23920            39  258039  314828  Newman`s Own
#
#               ticker_symbol
# Company 2018
# Newman`s Own              S
# Newman`s Own              S
# Newman`s Own              S
#
# [3 rows x 184 columns]

# %% [markdown]
# Same finding for 2018. Safe to drop for 2018 as well.

# %%
BAV_2018_clean = BAV_2018[~BAV_2018.index.duplicated()]

# %%
#Verify they're removed
#Test on YQRV
BAV_2018_clean[BAV_2018_clean['Brand_ID'] == 'YQRV']
# Out:
#              Brand_ID  Dupl_Index Category_CD  \
# Company 2018
# Newman`s Own     YQRV           1         F07
#
#                                                     Category_NM Sector  \
# Company 2018
# Newman`s Own  Ready-made Sauces such as Pasta & Barbecue Sauces   Food
#
#                Brand_Base  Unweighted_Brand_Base  Energized_Differentiation_R  \
# Company 2018
# Newman`s Own  3430.964111                   3513                    73.410965
#
#               Relevance_R   Esteem_R  ...  Total_Unaided_pct  Wave  Year  \
# Company 2018                          ...
# Newman`s Own    83.794273  82.629791  ...                NaN   NaN   NaN
#
#               Country  Brand_Key  Category_Key  BaseID  BSS_ID       company  \
# Company 2018
# Newman`s Own      NaN      23920           110  258039  314828  Newman`s Own
#
#               ticker_symbol
# Company 2018
# Newman`s Own              S
#
# [1 rows x 184 columns]

# %%
#Now let's drop the 'Dupl_Index' column since it's no longer needed
BAV_2019_clean.drop(['Dupl_Index'], axis=1)
BAV_2018_clean.drop(['Dupl_Index'], axis=1)
# Out:
#                 Brand_ID Category_CD            Category_NM  \
# Company 2018
# Acura                AVE         A01            Automobiles
# Alfa Romeo           CQK         A01            Automobiles
# Aston Martin         MKU         A01            Automobiles
# Audi                 AAA         A01            Automobiles
# Bentley              MLA         A01            Automobiles
# ...                  ...         ...                    ...
# FactSet             BDCK        Z99d  Financial Information
# FICO                WODP        Z99d  Financial Information
# LifeLock            BDCU        Z99d  Financial Information
# Quicken              BEJ        Z99d  Financial Information
# Thomson Reuters     WMKF        Z99d  Financial Information
#
#                                                 Sector   Brand_Base  \
# Company 2018
# Acura                                             Auto  1314.562012
# Alfa Romeo                                        Auto   942.608582
# Aston Martin                                      Auto  1040.751953
# Audi                                              Auto  1257.609009
# Bentley                                           Auto  1187.797974
# ...                                                ...          ...
# FactSet          Financial Services, Insurance & Banks   641.026917
# FICO             Financial Services, Insurance & Banks  2111.551025
# LifeLock         Financial Services, Insurance & Banks  3395.215088
# Quicken          Financial Services, Insurance & Banks  2103.879883
# Thomson Reuters  Financial Services, Insurance & Banks   498.500488
#
#                  Unweighted_Brand_Base  Energized_Differentiation_R  \
# Company 2018
# Acura                             1328                    59.728287
# Alfa Romeo                         961                    94.080544
# Aston Martin                      1065                    94.323143
# Audi                              1262                    94.226105
# Bentley                           1178                    94.808342
# ...                                ...                          ...
# FactSet                            591                    80.300827
# FICO                              2127                    20.766619
# LifeLock                          3446                    76.322174
# Quicken                           2176                    34.788937
# Thomson Reuters                    485                    28.141678
#
#                  Relevance_R   Esteem_R  Knowledge_R  ...  Total_Unaided_pct  \
# Company 2018                                          ...
# Acura              20.912178  71.858322    73.459488  ...                NaN
# Alfa Romeo          2.134886  27.947598    39.446869  ...                NaN
# Aston Martin        1.407084  26.880156    46.579330  ...                NaN
# Audi               11.159631  71.615723    72.052399  ...                NaN
# Bentley             1.746725  66.909264    58.563805  ...                NaN
# ...                      ...        ...          ...  ...                ...
# FactSet            71.518677  25.084909     5.385735  ...                NaN
# FICO               89.082970  75.691414    61.863174  ...                NaN
# LifeLock           32.411449  78.408539    59.582726  ...                NaN
# Quicken            20.524017  59.631248    55.118874  ...                NaN
# Thomson Reuters    42.163998  37.700146    14.992722  ...                NaN
#
#                  Wave  Year  Country  Brand_Key  Category_Key  BaseID  BSS_ID  \
# Company 2018
# Acura             NaN   NaN      NaN        551             5  258039  314828
# Alfa Romeo        NaN   NaN      NaN       1779             5  258039  314828
# Aston Martin      NaN   NaN      NaN       8496             5  258039  314828
# Audi              NaN   NaN      NaN          1             5  258039  314828
# Bentley           NaN   NaN      NaN       8502             5  258039  314828
# ...               ...   ...      ...        ...           ...     ...     ...
# FactSet           NaN   NaN      NaN      42090           488  258039  314828
# FICO              NaN   NaN      NaN     -25211           488  258039  314828
# LifeLock          NaN   NaN      NaN      42100           488  258039  314828
# Quicken           NaN   NaN      NaN        790           488  258039  314828
# Thomson Reuters   NaN   NaN      NaN     -24031           488  258039  314828
#
#                          company  ticker_symbol
# Company 2018
# Acura                      Acura           None
# Alfa Romeo            Alfa Romeo            RMO
# Aston Martin        Aston Martin           None
# Audi                        Audi           None
# Bentley                  Bentley            BSY
# ...                          ...            ...
# FactSet                  FactSet            FDS
# FICO                        FICO           FICO
# LifeLock                LifeLock           None
# Quicken                  Quicken           None
# Thomson Reuters  Thomson Reuters            TRI
#
# [3522 rows x 183 columns]

# %% [markdown]
# ### 8. Other missing values and empty columns

# %% [markdown]
# 1. Identify columns with irrelevant and missing values. Remove
# 2. Impute anything overtly missing

# %%
missing_2019 = pd.concat([BAV_2019_clean.isnull().sum(), 100 * BAV_2019_clean.isnull().mean()], axis=1)
missing_2019.columns=['missing_count_2019', '%']
missing_2019.sort_values(by='missing_count_2019', ascending=False).head(10)
# Out:
#                    missing_count_2019           %
# Country                          3661  100.000000
# Year                             3661  100.000000
# Wave                             3661  100.000000
# Total_Unaided_pct                3661  100.000000
# Top_of_Mind_pct                  3661  100.000000
# ticker_symbol                    1804   49.276154
# Trustworthy_R                       0    0.000000
# Sensuous_R                          0    0.000000
# Simple_R                            0    0.000000
# Social_R                            0    0.000000

# %%
dropped_2019 = BAV_2019_clean.drop(['Country', 'Year', 'Wave', 'Total_Unaided_pct', 'Top_of_Mind_pct', 'Dupl_Index'], axis=1)

# %%
dropped_2019.head()
# Out:
#              Brand_ID Category_CD  Category_NM Sector   Brand_Base  \
# Company 2019
# Acura             AVE         A01  Automobiles   Auto  1160.282959
# Alfa Romeo        CQK         A01  Automobiles   Auto   912.620789
# Aston Martin      MKU         A01  Automobiles   Auto   916.633179
# Audi              AAA         A01  Automobiles   Auto  1161.255005
# Bentley           MLA         A01  Automobiles   Auto  1147.734985
#
#               Unweighted_Brand_Base  Energized_Differentiation_R  Relevance_R  \
# Company 2019
# Acura                          1192                    72.705315    19.082125
# Alfa Romeo                      927                    91.980675     3.574879
# Aston Martin                    918                    97.101448     2.125604
# Audi                           1198                    92.801933    16.038647
# Bentley                        1150                    92.463768     2.608696
#
#                Esteem_R  Knowledge_R  ...  Would_miss_if_went_away_pct  \
# Company 2019                          ...
# Acura         71.545891    71.642509  ...                            0
# Alfa Romeo    17.681160    41.787441  ...                            0
# Aston Martin  52.705315    42.367149  ...                            0
# Audi          75.072464    69.275360  ...                            0
# Bentley       61.787441    56.763287  ...                            0
#
#               Community_Engage_C  Product_Performance_C  \
# Company 2019
# Acura                          0                      0
# Alfa Romeo                     0                      0
# Aston Martin                   0                      0
# Audi                           0                      0
# Bentley                        0                      0
#
#               Treatment_Understand_C  Brand_Key  Category_Key  BaseID  BSS_ID  \
# Company 2019
# Acura                              0        551             5  268911  329227
# Alfa Romeo                         0       1779             5  268911  329227
# Aston Martin                       0       8496             5  268911  329227
# Audi                               0          1             5  268911  329227
# Bentley                            0       8502             5  268911  329227
#
#                    company  ticker_symbol
# Company 2019
# Acura                Acura           None
# Alfa Romeo      Alfa Romeo            RMO
# Aston Martin  Aston Martin           None
# Audi                  Audi           None
# Bentley            Bentley            BSY
#
# [5 rows x 178 columns]

# %%
BAV_2019_clean = dropped_2019

# %%
BAV_2019_clean.head()
# Out:
#              Brand_ID Category_CD  Category_NM Sector   Brand_Base  \
# Company 2019
# Acura             AVE         A01  Automobiles   Auto  1160.282959
# Alfa Romeo        CQK         A01  Automobiles   Auto   912.620789
# Aston Martin      MKU         A01  Automobiles   Auto   916.633179
# Audi              AAA         A01  Automobiles   Auto  1161.255005
# Bentley           MLA         A01  Automobiles   Auto  1147.734985
#
#               Unweighted_Brand_Base  Energized_Differentiation_R  Relevance_R  \
# Company 2019
# Acura                          1192                    72.705315    19.082125
# Alfa Romeo                      927                    91.980675     3.574879
# Aston Martin                    918                    97.101448     2.125604
# Audi                           1198                    92.801933    16.038647
# Bentley                        1150                    92.463768     2.608696
#
#                Esteem_R  Knowledge_R  ...  Would_miss_if_went_away_pct  \
# Company 2019                          ...
# Acura         71.545891    71.642509  ...                            0
# Alfa Romeo    17.681160    41.787441  ...                            0
# Aston Martin  52.705315    42.367149  ...                            0
# Audi          75.072464    69.275360  ...                            0
# Bentley       61.787441    56.763287  ...                            0
#
#               Community_Engage_C  Product_Performance_C  \
# Company 2019
# Acura                          0                      0
# Alfa Romeo                     0                      0
# Aston Martin                   0                      0
# Audi                           0                      0
# Bentley                        0                      0
#
#               Treatment_Understand_C  Brand_Key  Category_Key  BaseID  BSS_ID  \
# Company 2019
# Acura                              0        551             5  268911  329227
# Alfa Romeo                         0       1779             5  268911  329227
# Aston Martin                       0       8496             5  268911  329227
# Audi                               0          1             5  268911  329227
# Bentley                            0       8502             5  268911  329227
#
#                    company  ticker_symbol
# Company 2019
# Acura                Acura           None
# Alfa Romeo      Alfa Romeo            RMO
# Aston Martin  Aston Martin           None
# Audi                  Audi           None
# Bentley            Bentley            BSY
#
# [5 rows x 178 columns]

# %%
missing_2018 = pd.concat([BAV_2018_clean.isnull().sum(), 100 * BAV_2018_clean.isnull().mean()], axis=1)
missing_2018.columns=['missing_count_2018', '%']
missing_2018.sort_values(by='missing_count_2018', ascending=False).head(10)
# Out:
#                    missing_count_2018           %
# Country                          3522  100.000000
# Year                             3522  100.000000
# Wave                             3522  100.000000
# Total_Unaided_pct                3522  100.000000
# Top_of_Mind_pct                  3522  100.000000
# ticker_symbol                    1678   47.643384
# Sector                              1    0.028393
# Unapproachable_R                    0    0.000000
# Simple_R                            0    0.000000
# Social_R                            0    0.000000

# %%
dropped_2018 = BAV_2018_clean.drop(['Country', 'Year', 'Wave', 'Total_Unaided_pct', 'Top_of_Mind_pct', 'Dupl_Index'], axis=1)

# %%
dropped_2018.head()
# Out:
#              Brand_ID Category_CD  Category_NM Sector   Brand_Base  \
# Company 2018
# Acura             AVE         A01  Automobiles   Auto  1314.562012
# Alfa Romeo        CQK         A01  Automobiles   Auto   942.608582
# Aston Martin      MKU         A01  Automobiles   Auto  1040.751953
# Audi              AAA         A01  Automobiles   Auto  1257.609009
# Bentley           MLA         A01  Automobiles   Auto  1187.797974
#
#               Unweighted_Brand_Base  Energized_Differentiation_R  Relevance_R  \
# Company 2018
# Acura                          1328                    59.728287    20.912178
# Alfa Romeo                      961                    94.080544     2.134886
# Aston Martin                   1065                    94.323143     1.407084
# Audi                           1262                    94.226105    11.159631
# Bentley                        1178                    94.808342     1.746725
#
#                Esteem_R  Knowledge_R  ...  Would_miss_if_went_away_pct  \
# Company 2018                          ...
# Acura         71.858322    73.459488  ...                            0
# Alfa Romeo    27.947598    39.446869  ...                            0
# Aston Martin  26.880156    46.579330  ...                            0
# Audi          71.615723    72.052399  ...                            0
# Bentley       66.909264    58.563805  ...                            0
#
#               Community_Engage_C  Product_Performance_C  \
# Company 2018
# Acura                          0                      0
# Alfa Romeo                     0                      0
# Aston Martin                   0                      0
# Audi                           0                      0
# Bentley                        0                      0
#
#               Treatment_Understand_C  Brand_Key  Category_Key  BaseID  BSS_ID  \
# Company 2018
# Acura                              0        551             5  258039  314828
# Alfa Romeo                         0       1779             5  258039  314828
# Aston Martin                       0       8496             5  258039  314828
# Audi                               0          1             5  258039  314828
# Bentley                            0       8502             5  258039  314828
#
#                    company  ticker_symbol
# Company 2018
# Acura                Acura           None
# Alfa Romeo      Alfa Romeo            RMO
# Aston Martin  Aston Martin           None
# Audi                  Audi           None
# Bentley            Bentley            BSY
#
# [5 rows x 178 columns]

# %%
BAV_2018_clean = dropped_2018
BAV_2018_clean.head()
# Out:
#              Brand_ID Category_CD  Category_NM Sector   Brand_Base  \
# Company 2018
# Acura             AVE         A01  Automobiles   Auto  1314.562012
# Alfa Romeo        CQK         A01  Automobiles   Auto   942.608582
# Aston Martin      MKU         A01  Automobiles   Auto  1040.751953
# Audi              AAA         A01  Automobiles   Auto  1257.609009
# Bentley           MLA         A01  Automobiles   Auto  1187.797974
#
#               Unweighted_Brand_Base  Energized_Differentiation_R  Relevance_R  \
# Company 2018
# Acura                          1328                    59.728287    20.912178
# Alfa Romeo                      961                    94.080544     2.134886
# Aston Martin                   1065                    94.323143     1.407084
# Audi                           1262                    94.226105    11.159631
# Bentley                        1178                    94.808342     1.746725
#
#                Esteem_R  Knowledge_R  ...  Would_miss_if_went_away_pct  \
# Company 2018                          ...
# Acura         71.858322    73.459488  ...                            0
# Alfa Romeo    27.947598    39.446869  ...                            0
# Aston Martin  26.880156    46.579330  ...                            0
# Audi          71.615723    72.052399  ...                            0
# Bentley       66.909264    58.563805  ...                            0
#
#               Community_Engage_C  Product_Performance_C  \
# Company 2018
# Acura                          0                      0
# Alfa Romeo                     0                      0
# Aston Martin                   0                      0
# Audi                           0                      0
# Bentley                        0                      0
#
#               Treatment_Understand_C  Brand_Key  Category_Key  BaseID  BSS_ID  \
# Company 2018
# Acura                              0        551             5  258039  314828
# Alfa Romeo                         0       1779             5  258039  314828
# Aston Martin                       0       8496             5  258039  314828
# Audi                               0          1             5  258039  314828
# Bentley                            0       8502             5  258039  314828
#
#                    company  ticker_symbol
# Company 2018
# Acura                Acura           None
# Alfa Romeo      Alfa Romeo            RMO
# Aston Martin  Aston Martin           None
# Audi                  Audi           None
# Bentley            Bentley            BSY
#
# [5 rows x 178 columns]

# %% [markdown]
# Find and see if missing sector value from 2018 can be imputed.

# %%
BAV_2018_clean.loc[BAV_2018_clean['Sector'].isnull()]
# Out:
#              Brand_ID Category_CD                          Category_NM Sector  \
# Company 2018
# WeLive           BLAL        T01o  Living Space/Apartments/Communities    NaN
#
#               Brand_Base  Unweighted_Brand_Base  Energized_Differentiation_R  \
# Company 2018
# WeLive        429.231201                    417                     74.62397
#
#               Relevance_R  Esteem_R  Knowledge_R  ...  \
# Company 2018                                      ...
# WeLive          71.373123   28.4328     1.940805  ...
#
#               Would_miss_if_went_away_pct  Community_Engage_C  \
# Company 2018
# WeLive                                  0                   0
#
#               Product_Performance_C  Treatment_Understand_C  Brand_Key  \
# Company 2018
# WeLive                            0                       0      47447
#
#               Category_Key  BaseID  BSS_ID  company  ticker_symbol
# Company 2018
# WeLive                 811  258039  314828   WeLive           None
#
# [1 rows x 178 columns]

# %% [markdown]
# Interesting. I know from looking at this, this is part of the WeWork company. Not sure what sector to give it. Since the data is ordered by sector, will find the values above and below this one to see if we can impute one of those.

# %%
WeLive_index = BAV_2018_clean.index.get_loc('WeLive')
WeLive_prox = [WeLive_index-1, WeLive_index, WeLive_index+1]
BAV_2018_clean.iloc[WeLive_prox]
# Out:
#              Brand_ID Category_CD                          Category_NM  \
# Company 2018
# Vivid Seats      BGQW        T01n         Tickets and Booking services
# WeLive           BLAL        T01o  Living Space/Apartments/Communities
# Bellagio         WAAT         T02       Travel, Vacation & Theme Parks
#
#                               Sector  Brand_Base  Unweighted_Brand_Base  \
# Company 2018
# Vivid Seats   Travel & Entertainment  694.865784                    654
# WeLive                           NaN  429.231201                    417
# Bellagio      Travel & Entertainment  882.959412                    867
#
#               Energized_Differentiation_R  Relevance_R   Esteem_R  \
# Company 2018
# Vivid Seats                     68.898590    48.568657  25.764193
# WeLive                          74.623970    71.373123  28.432800
# Bellagio                        80.446388    32.751091  55.992237
#
#               Knowledge_R  ...  Would_miss_if_went_away_pct  \
# Company 2018               ...
# Vivid Seats      6.065017  ...                            0
# WeLive           1.940805  ...                            0
# Bellagio        40.320232  ...                            0
#
#               Community_Engage_C  Product_Performance_C  \
# Company 2018
# Vivid Seats                    0                      0
# WeLive                         0                      0
# Bellagio                       0                      0
#
#               Treatment_Understand_C  Brand_Key  Category_Key  BaseID  BSS_ID  \
# Company 2018
# Vivid Seats                        0      44494           800  258039  314828
# WeLive                             0      47447           811  258039  314828
# Bellagio                           0     -15673           141  258039  314828
#
#                   company  ticker_symbol
# Company 2018
# Vivid Seats   Vivid Seats           None
# WeLive             WeLive           None
# Bellagio         Bellagio           None
#
# [3 rows x 178 columns]

# %%
BAV_2018_clean.at['WeLive', 'Sector'] = 'Travel & Entertainment'

# %%
print(BAV_2018_clean.at['WeLive', 'Sector'])
# Out:
# Travel & Entertainment

# %%
#verify
BAV_2018_clean.loc[BAV_2018_clean['Sector'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Brand_ID, Category_CD, Category_NM, Sector, Brand_Base, Unweighted_Brand_Base, Energized_Differentiation_R, Relevance_R, Esteem_R, Knowledge_R, Brand_Stature_R, Brand_Strength_R, Brand_Asset_R, Usage_Preference_Brand_Base, Use_Regularly_Use_pct, Use_Occasionally_pct, Lapsed_User_pct, Never_Used_pct, One_I_Prefer_pct, One_of_several_pct, Only_if_no_alternative_pct, Would_never_consider_pct, Total_Users_pct, Total_Prefer_pct, Energized_Differentiation_C, Relevance_C, Esteem_C, Knowledge_C, Brand_Stature_C, Brand_Strength_C, Brand_Asset_C, Different_pct, Distinctive_pct, Unique_pct, Dynamic_pct, Innovative_pct, Leader_pct, Reliable_pct, High_quality_pct, Arrogant_pct, Authentic_pct, Best_Brand_pct, Carefree_pct, Cares_Customers_pct, Charming_pct, Cool_pct, Creative_pct, Daring_pct, Down_to_Earth_pct, Energetic_pct, Friendly_pct, Fun_pct, Gaining_In_Popularity_pct, Glamorous_pct, Good_Value_pct, Healthy_pct, Helpful_pct, High_Performance_pct, Independent_pct, Intelligent_pct, Kind_pct, Obliging_pct, Original_pct, Prestigious_pct, Progressive_pct, Restrained_pct, Rugged_pct, Sensuous_pct, Simple_pct, Social_pct, Socially_Responsible_pct, Straightforward_pct, Stylish_pct, Traditional_pct, Trendy_pct, Trustworthy_pct, Unapproachable_pct, Up_To_Date_pct, Upper_Class_pct, Visionary_pct, Worth_More_pct, Different_R, Distinctive_R, Unique_R, Dynamic_R, Innovative_R, Leader_R, Reliable_R, High_Quality_R, Arrogant_R, Authentic_R, Best_Brand_R, Carefree_R, Cares_Customers_R, Charming_R, Cool_R, Creative_R, Daring_R, Down_To_Earth_R, Energetic_R, ...]
# Index: []
#
# [0 rows x 178 columns]

# %%
zero_2019 = BAV_2019_clean.loc[:, (BAV_2019_clean == 0).all()]
print(zero_2019.columns)
# Out:
# Index(['Obliging_pct', 'Restrained_pct', 'DO NOT USE', 'Belong_to_a_club_pct',
#        'Best_option_available_pct', 'Buy_on_sale_only_pct',
#        'Fairly_priced_pct', 'Feel_loyal_pct', 'Goes_out_of_its_way_pct',
#        'Identify_with_other_users_pct', 'Interested_learning_more_pct',
#        'Interested_special_events_pct', 'Meets_my_needs_completely_pct',
#        'My_kind_of_brand_pct', 'One_of_my_favorite_brands_pct',
#        'Resolves_conflicts_well_pct', 'Strongest_relationship_pct',
#        'Want_my_business_pct', 'Worth_a_premium_price_pct',
#        'Would_miss_if_went_away_pct', 'Community_Engage_C',
#        'Product_Performance_C', 'Treatment_Understand_C'],
#       dtype='object')

# %%
#drop zero only columns 2019
BAV_2019_cleaned = BAV_2019_clean.drop(['Obliging_pct', 'Restrained_pct', 'DO NOT USE', 'Belong_to_a_club_pct',
       'Best_option_available_pct', 'Buy_on_sale_only_pct',
       'Fairly_priced_pct', 'Feel_loyal_pct', 'Goes_out_of_its_way_pct',
       'Identify_with_other_users_pct', 'Interested_learning_more_pct',
       'Interested_special_events_pct', 'Meets_my_needs_completely_pct',
       'My_kind_of_brand_pct', 'One_of_my_favorite_brands_pct',
       'Resolves_conflicts_well_pct', 'Strongest_relationship_pct',
       'Want_my_business_pct', 'Worth_a_premium_price_pct',
       'Would_miss_if_went_away_pct', 'Community_Engage_C',
       'Product_Performance_C', 'Treatment_Understand_C'], axis=1)

# %%
BAV_2019_cleaned.head()
# Out:
#              Brand_ID Category_CD  Category_NM Sector   Brand_Base  \
# Company 2019
# Acura             AVE         A01  Automobiles   Auto  1160.282959
# Alfa Romeo        CQK         A01  Automobiles   Auto   912.620789
# Aston Martin      MKU         A01  Automobiles   Auto   916.633179
# Audi              AAA         A01  Automobiles   Auto  1161.255005
# Bentley           MLA         A01  Automobiles   Auto  1147.734985
#
#               Unweighted_Brand_Base  Energized_Differentiation_R  Relevance_R  \
# Company 2019
# Acura                          1192                    72.705315    19.082125
# Alfa Romeo                      927                    91.980675     3.574879
# Aston Martin                    918                    97.101448     2.125604
# Audi                           1198                    92.801933    16.038647
# Bentley                        1150                    92.463768     2.608696
#
#                Esteem_R  Knowledge_R  ...  Do Not Use.3  Distant_C  \
# Company 2019                          ...
# Acura         71.545891    71.642509  ...      6.774314   6.849280
# Alfa Romeo    17.681160    41.787441  ...      5.463263   9.425364
# Aston Martin  52.705315    42.367149  ...      5.717941  11.362800
# Audi          75.072464    69.275360  ...      6.408536   8.952747
# Bentley       61.787441    56.763287  ...      4.879201  11.695000
#
#               DiagnosticsBase  Recommend_to_a_friend_pct  Brand_Key  \
# Company 2019
# Acura             3927.775879                   9.953999        551
# Alfa Romeo        3927.775879                   4.776871       1779
# Aston Martin      3927.775879                   5.559846       8496
# Audi              3927.775879                   9.149771          1
# Bentley           3927.775879                   6.758671       8502
#
#               Category_Key  BaseID  BSS_ID       company  ticker_symbol
# Company 2019
# Acura                    5  268911  329227         Acura           None
# Alfa Romeo               5  268911  329227    Alfa Romeo            RMO
# Aston Martin             5  268911  329227  Aston Martin           None
# Audi                     5  268911  329227          Audi           None
# Bentley                  5  268911  329227       Bentley            BSY
#
# [5 rows x 155 columns]

# %%
zero_2018 = BAV_2018_clean.loc[:, (BAV_2018_clean == 0).all()]
print(zero_2018.columns)
# Out:
# Index(['DO NOT USE', 'Belong_to_a_club_pct', 'Best_option_available_pct',
#        'Buy_on_sale_only_pct', 'Fairly_priced_pct', 'Feel_loyal_pct',
#        'Goes_out_of_its_way_pct', 'Identify_with_other_users_pct',
#        'Interested_learning_more_pct', 'Interested_special_events_pct',
#        'Meets_my_needs_completely_pct', 'My_kind_of_brand_pct',
#        'One_of_my_favorite_brands_pct', 'Resolves_conflicts_well_pct',
#        'Strongest_relationship_pct', 'Want_my_business_pct',
#        'Worth_a_premium_price_pct', 'Would_miss_if_went_away_pct',
#        'Community_Engage_C', 'Product_Performance_C',
#        'Treatment_Understand_C'],
#       dtype='object')

# %%
#drop zero only columns 2018
BAV_2018_cleaned = BAV_2018_clean.drop(['Obliging_pct', 'Restrained_pct', 'DO NOT USE', 'Belong_to_a_club_pct', 'Best_option_available_pct',
       'Buy_on_sale_only_pct', 'Fairly_priced_pct', 'Feel_loyal_pct',
       'Goes_out_of_its_way_pct', 'Identify_with_other_users_pct',
       'Interested_learning_more_pct', 'Interested_special_events_pct',
       'Meets_my_needs_completely_pct', 'My_kind_of_brand_pct',
       'One_of_my_favorite_brands_pct', 'Resolves_conflicts_well_pct',
       'Strongest_relationship_pct', 'Want_my_business_pct',
       'Worth_a_premium_price_pct', 'Would_miss_if_went_away_pct',
       'Community_Engage_C', 'Product_Performance_C',
       'Treatment_Understand_C'], axis=1)

# %%
BAV_2018_cleaned.head()
# Out:
#              Brand_ID Category_CD  Category_NM Sector   Brand_Base  \
# Company 2018
# Acura             AVE         A01  Automobiles   Auto  1314.562012
# Alfa Romeo        CQK         A01  Automobiles   Auto   942.608582
# Aston Martin      MKU         A01  Automobiles   Auto  1040.751953
# Audi              AAA         A01  Automobiles   Auto  1257.609009
# Bentley           MLA         A01  Automobiles   Auto  1187.797974
#
#               Unweighted_Brand_Base  Energized_Differentiation_R  Relevance_R  \
# Company 2018
# Acura                          1328                    59.728287    20.912178
# Alfa Romeo                      961                    94.080544     2.134886
# Aston Martin                   1065                    94.323143     1.407084
# Audi                           1262                    94.226105    11.159631
# Bentley                        1178                    94.808342     1.746725
#
#                Esteem_R  Knowledge_R  ...  No_Nonsense_C  Distant_C  \
# Company 2018                          ...
# Acura         71.858322    73.459488  ...       6.920542   6.546608
# Alfa Romeo    27.947598    39.446869  ...       4.981933  10.927900
# Aston Martin  26.880156    46.579330  ...       4.764266  10.235070
# Audi          71.615723    72.052399  ...       7.041301   8.581500
# Bentley       66.909264    58.563805  ...       5.260837  12.021740
#
#               DiagnosticsBase  Recommend_to_a_friend_pct  Brand_Key  \
# Company 2018
# Acura              4128.00293                   9.632626        551
# Alfa Romeo         4128.00293                   5.360558       1779
# Aston Martin       4128.00293                   6.165359       8496
# Audi               4128.00293                   8.403893          1
# Bentley            4128.00293                   6.453038       8502
#
#               Category_Key  BaseID  BSS_ID       company  ticker_symbol
# Company 2018
# Acura                    5  258039  314828         Acura           None
# Alfa Romeo               5  258039  314828    Alfa Romeo            RMO
# Aston Martin             5  258039  314828  Aston Martin           None
# Audi                     5  258039  314828          Audi           None
# Bentley                  5  258039  314828       Bentley            BSY
#
# [5 rows x 155 columns]

# %% [markdown]
# ### 9. Verify Data is in good shape

# %%
BAV_2019_cleaned[relevant_columns]
# Out:
#                  Relevance_R   Esteem_R  Knowledge_R  Brand_Stature_R  \
# Company 2019
# Acura              19.082125  71.545891    71.642509        74.057968
# Alfa Romeo          3.574879  17.681160    41.787441        35.893719
# Aston Martin        2.125604  52.705315    42.367149        49.275364
# Audi               16.038647  75.072464    69.275360        74.927536
# Bentley             2.608696  61.787441    56.763287        61.594204
# ...                      ...        ...          ...              ...
# Thomson Reuters    47.681160  49.758453    14.975845        21.256039
# UltraFICO          81.932365  18.067633    11.111111         9.178744
# FlightAware        68.454109  51.787441     4.927536        12.173913
# FlightView         45.893719  22.898550     1.739130         2.415459
# Gogo Inflight      54.927536   7.342995     4.106280         1.304348
#
#                  Brand_Strength_R  Different_R  Distinctive_R   Unique_R  \
# Company 2019
# Acura                   41.884056    38.260868      83.961349  42.850243
# Alfa Romeo              39.227055    64.637680      97.342995  86.473427
# Aston Martin            44.637680    81.642509      99.178741  96.328499
# Audi                    64.589371    53.381641      95.652176  78.599037
# Bentley                 35.120773    72.560387      98.888885  88.454109
# ...                           ...          ...            ...        ...
# Thomson Reuters         39.516907    37.777779      22.801933  18.019323
# UltraFICO               73.526573    60.531403      14.830918  54.879227
# FlightAware             75.507248    84.782608      34.541061  54.009663
# FlightView              81.932365    83.671501      46.666668  88.550728
# Gogo Inflight           87.439613    98.067635      59.758453  94.202896
#
#                  Dynamic_R  Innovative_R  ...  Stylish_R  Traditional_R  \
# Company 2019                              ...
# Acura            86.183578     73.526573  ...  90.483093      42.415459
# Alfa Romeo       91.545891     77.342995  ...  91.739128      20.531401
# Aston Martin     94.589371     75.845413  ...  94.444443      20.966183
# Audi             96.473427     85.700485  ...  96.473427      30.289856
# Bentley          92.995171     51.352657  ...  92.946861      63.478260
# ...                    ...           ...  ...        ...            ...
# Thomson Reuters  78.502419     54.106281  ...   6.328502      29.903381
# UltraFICO        78.019325     59.951691  ...  49.516907       8.743961
# FlightAware      57.584541     89.806763  ...  77.101448      46.811596
# FlightView       87.681160     97.487923  ...  69.710144      49.082127
# Gogo Inflight    72.318840     95.217392  ...  79.082123      55.217392
#
#                   Trendy_R  Trustworthy_R  Unapproachable_R  Up_To_Date_R  \
# Company 2019
# Acura            74.154587      63.236713         61.062801     68.695656
# Alfa Romeo       60.483093       6.280193         92.077293     22.222221
# Aston Martin     65.458939      21.932367         98.019325     35.507248
# Audi             80.821259      58.067635         72.173912     64.299515
# Bentley          51.207729      21.014492         97.198067     35.893719
# ...                    ...            ...               ...           ...
# Thomson Reuters  23.574879      43.140095         61.545895     44.734299
# UltraFICO        19.951691      12.946860         94.830917     59.613525
# FlightAware      77.777779      19.178743         92.367149     86.763283
# FlightView       39.033817      17.826086         62.560387     38.019325
# Gogo Inflight    87.101448       8.357488         70.483093     39.516907
#
#                  Upper_Class_R  Visionary_R  Worth_More_R  ticker_symbol
# Company 2019
# Acura                94.782608    79.178741     73.091789           None
# Alfa Romeo           98.502419    57.922707     69.227051            RMO
# Aston Martin         99.227051    76.425117     75.410629           None
# Audi                 98.647346    67.922707     75.072464           None
# Bentley              99.710144    59.468597     91.207733            BSY
# ...                        ...          ...           ...            ...
# Thomson Reuters      58.550724    33.333332     11.111111            TRI
# UltraFICO            59.806763    43.913044     41.111111           None
# FlightAware          77.053139    57.681160     46.859905           None
# FlightView           84.734299    74.154587     43.864735           None
# Gogo Inflight        68.840576    93.768112     16.859903           GOGO
#
# [3661 rows x 54 columns]

# %%
BAV_2018_cleaned[relevant_columns]
# Out:
#                  Relevance_R   Esteem_R  Knowledge_R  Brand_Stature_R  \
# Company 2018
# Acura              20.912178  71.858322    73.459488        74.915092
# Alfa Romeo          2.134886  27.947598    39.446869        39.543911
# Aston Martin        1.407084  26.880156    46.579330        43.085880
# Audi               11.159631  71.615723    72.052399        74.332848
# Bentley             1.746725  66.909264    58.563805        64.531784
# ...                      ...        ...          ...              ...
# FactSet            71.518677  25.084909     5.385735         5.919456
# FICO               89.082970  75.691414    61.863174        72.343521
# LifeLock           32.411449  78.408539    59.582726        72.440559
# Quicken            20.524017  59.631248    55.118874        60.164967
# Thomson Reuters    42.163998  37.700146    14.992722        17.952450
#
#                  Brand_Strength_R  Different_R  Distinctive_R   Unique_R  \
# Company 2018
# Acura                   35.128578    38.961670      72.731682  36.923824
# Alfa Romeo              37.020863    80.397865      97.816597  91.848618
# Aston Martin            31.246967    80.009705      98.495872  91.606018
# Audi                    63.027657    61.475014      94.808342  85.201355
# Bentley                 36.875301    81.125664      99.223679  97.573990
# ...                           ...          ...            ...        ...
# FactSet                 81.465309    89.034447      40.999516  81.028625
# FICO                    63.755459    17.709850      27.025715  21.300339
# LifeLock                57.738960    50.800583      50.557983  68.801552
# Quicken                 20.718098    37.554585      22.416304  11.111111
# Thomson Reuters         28.723921    51.091702      16.011644  31.246967
#
#                  Dynamic_R  Innovative_R  ...  Stylish_R  Traditional_R  \
# Company 2018                              ...
# Acura            74.090248     69.383797  ...  90.101891      10.965550
# Alfa Romeo       94.517227     50.606503  ...  91.703056      20.329937
# Aston Martin     91.120811     63.949539  ...  91.120811       2.328967
# Audi             96.846191     87.142166  ...  93.837944      36.923824
# Bentley          88.937408     47.743813  ...  95.099464      68.413391
# ...                    ...           ...  ...        ...            ...
# FactSet          80.640465     74.526932  ...  48.617176      45.366325
# FICO             43.813683     37.409023  ...  19.553616      56.089275
# LifeLock         73.556526     93.110138  ...   5.143135       5.579815
# Quicken          42.455120     78.748184  ...   1.018923      14.944201
# Thomson Reuters  78.554100      6.501698  ...  69.820473      27.656477
#
#                   Trendy_R  Trustworthy_R  Unapproachable_R  Up_To_Date_R  \
# Company 2018
# Acura            73.896164      62.785057         66.472588     57.836002
# Alfa Romeo       75.109169      11.644833         98.010674     49.102379
# Aston Martin     55.749638      11.887433         97.185829      9.024745
# Audi             80.252304      32.411449         81.659386     56.720039
# Bentley          59.485687      34.788937         98.835518     26.491995
# ...                    ...            ...               ...           ...
# FactSet          67.006310      49.878700         93.013100     75.836975
# FICO             14.653081      76.904419         77.535179     67.879669
# LifeLock         44.492966      91.557495         39.883553     91.169334
# Quicken          20.087336      56.234837         45.172245     80.058228
# Thomson Reuters  17.612810      46.433769         78.505577     44.056282
#
#                  Upper_Class_R  Visionary_R  Worth_More_R  ticker_symbol
# Company 2018
# Acura                93.498299    85.929161     58.466763           None
# Alfa Romeo           98.447357    44.347404     79.815620            RMO
# Aston Martin         99.369240    56.914120     81.125664           None
# Audi                 97.719551    73.750603     81.901993           None
# Bentley              99.805916    52.547306     90.781174            BSY
# ...                        ...          ...           ...            ...
# FactSet              59.437168    68.850075     31.635128            FDS
# FICO                 37.166424    54.051430     18.292091           FICO
# LifeLock             66.957787    95.245026     76.467735           None
# Quicken              14.313440    64.434738     18.825813           None
# Thomson Reuters      63.803978    81.707909     15.963124            TRI
#
# [3522 rows x 54 columns]

# %%
BAV_2019_cleaned.dtypes.value_counts()
# Out:
# float64    144
# object       6
# int64        5
# dtype: int64

# %%
BAV_2018_cleaned.dtypes.value_counts()
# Out:
# float64    144
# object       6
# int64        5
# dtype: int64

# %% [markdown]
# ### 10. Save Data

# %% [markdown]
# Looking good. Let's save these files out.

# %%
BAV_2018_cleaned.to_csv("../data/BAV_2018.csv")

# %%
BAV_2019_cleaned.to_csv("../data/BAV_2019.csv")

# %% [markdown]
# ### 11. Summary

# %% [markdown]
# The original brand datasets contained ~3300 rows and 185 columns. Upon further inspection of the data, the decision was made two focus on two years of the brand perception data instead of 3. Since the attributes were inconsistent between 2017 and 2018. Between the 2018 and 2019 data, there was reason to make some drops. After dropping duplicate companies, stripping whitespaces in Brand Ids and dropping about 30 null comulms, there was only one missing sector value to manually impute (WeLive).
#
# The Polygon API was used to add stock ticker values to the datasets. Hypothesis was that about 10% of brands would be accuratley matched. After pulling the tickers that corresponded to major U.S. financial exchanges, the match rate was about 23%. These are not all accurate and it was found that there are over 320 duplicate ticker values. This will have to be addressed in further analaysis but means that the actual match rate should end up closer to 15%—still plenty enough for further analysis.
#
# The end state of the data after wrangling is two data frames (one for each year 2018 and 2019) each with 155 columns. There are some companies that aren't present in both years, but that will be addressed if necessary in future phases. Other data still to collect is using the stock ticker values to gather financial data on each matched company. This will be done in a future phase with the Polygon and/or y2fin APIs.
